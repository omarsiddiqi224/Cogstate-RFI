# %%
import os
import shutil
from tqdm import tqdm

# --- Core Application Imports ---
from config.config import Config
from rfiprocessor.utils.logger import get_logger
from rfiprocessor.utils.wlak_dir import list_all_file_paths
from rfiprocessor.services.markdown_converter import MarkdownConverter, ProcessorType
from rfiprocessor.core.agents.document_classifier import DocumentClassifierAgent

# --- Database Imports ---
from rfiprocessor.db.database import init_db, get_db_session
from rfiprocessor.services.db_handler import DatabaseHandler
from rfiprocessor.db.db_models import IngestionStatus

# --- Initial Setup ---
config = Config()
logger = get_logger(__name__)

def run_markdown_conversion_pipeline():
    """
    Scans for new files, converts them to markdown, and tracks progress in the database.
    """

    # --- Step 1: Markdown Conversion ---
    logger.info("--- Starting Markdown Conversion Pipeline ---")
    
    # Initialize services
    converter = MarkdownConverter()
    classifier = DocumentClassifierAgent()
    
    # Get a database session and initialize the handler
    db_session_generator = get_db_session()
    db_session = next(db_session_generator)
    try:
        db_handler = DatabaseHandler(db_session)

        # 1. Scan the incoming directory for all files
        all_files = list_all_file_paths(config.INCOMING_DATA_PATH)
        
        # 2. Register all found files in the database if they don't exist
        logger.info(f"Found {len(all_files)} files. Registering new files in the database...")
        for file_path in all_files:
            # This will add the document if new, or get the existing one.
            db_handler.add_or_get_document(source_filepath=file_path)
        
        # 3. Fetch only the documents that are pending conversion
        pending_docs = db_handler.get_documents_by_status(IngestionStatus.PENDING)
        
        # Filter out unsupported files
        valid_docs = [
            doc for doc in pending_docs 
            if any(doc.source_filename.lower().endswith(ext) for ext in config.VALID_FILE_EXTNS)
        ]
        
        if not valid_docs:
            logger.info("No new documents to convert. Pipeline finished.")
            return

        logger.info(f"Found {len(valid_docs)} new documents to process.")

        # 4. Process each pending document
        for doc in tqdm(valid_docs, desc="Converting files to Markdown"):
            try:
                logger.info(f"Processing document: {doc.source_filename} (ID: {doc.id})")
                
                # Determine which processor to use
                processor_to_use = ProcessorType.MARKITDOWN
                if any(doc.source_filename.lower().endswith(ext) for ext in config.UNSTRD_FILE_EXTNS):
                    processor_to_use = ProcessorType.UNSTRUCTURED

                # Convert the file to markdown
                markdown_content, markdown_path = converter.convert_to_markdown(
                    file_path=doc.source_filepath,
                    processor=processor_to_use
                )
                
                # Move the original raw file to the processed directory
                destination_path = os.path.join(config.PROCESSED_DATA_PATH, doc.source_filename)
                os.makedirs(os.path.dirname(destination_path), exist_ok=True)
                shutil.move(doc.source_filepath, destination_path)
                
                # Update the document record in the database with the new status and paths
                updates = {
                    "markdown_filepath": markdown_path,
                    "processed_filepath": destination_path,
                    "ingestion_status": IngestionStatus.MARKDOWN_CONVERTED,
                    "error_message": None # Clear any previous errors
                }
                db_handler.update_document(doc.id, updates)
                logger.info(f"Successfully converted and moved document ID {doc.id}.")

            except Exception as e:
                logger.error(f"Error processing document ID {doc.id} ('{doc.source_filename}'): {e}", exc_info=True)
                # Update the document record to reflect the failure
                db_handler.update_document(
                    doc.id,
                    {
                        "ingestion_status": IngestionStatus.FAILED,
                        "error_message": str(e)
                    }
                )

    finally:
        # Ensure the database session is closed
        db_session.close()
        logger.info("--- Markdown Conversion Pipeline Finished ---")

    # Get a database session and initialize the handler
    db_session_generator = get_db_session()
    db_session = next(db_session_generator)
    try:
        db_handler = DatabaseHandler(db_session)

        # --- Step 2: Document Classification ---
        logger.info("--- Starting Document Classification Step ---")
        docs_to_classify = db_handler.get_documents_by_status(IngestionStatus.MARKDOWN_CONVERTED)
        
        if not docs_to_classify:
            logger.info("No new documents to classify.")
        else:
            logger.info(f"Found {len(docs_to_classify)} documents to classify.")

        for doc in tqdm(docs_to_classify, desc="Classifying documents"):
            try:
                logger.info(f"Classifying document: {doc.source_filename} (ID: {doc.id})")
                
                # Read the markdown content from the file
                with open(doc.markdown_filepath, 'r', encoding='utf-8') as f:
                    markdown_content = f.read()
                
                # Call the classifier agent
                classification = classifier.classify(markdown_content)
                
                # Update the document in the database
                updates = {
                    "document_type": classification.get("document_type"),
                    "document_grade": classification.get("document_grade"),
                    "ingestion_status": IngestionStatus.CLASSIFIED,
                    "error_message": None
                }
                db_handler.update_document(doc.id, updates)
                logger.info(f"Successfully classified document ID {doc.id}.")

            except Exception as e:
                logger.error(f"Error classifying document ID {doc.id}: {e}", exc_info=True)
                db_handler.update_document(
                    doc.id,
                    {"ingestion_status": IngestionStatus.FAILED, "error_message": f"Classification failed: {e}"}
                )

    finally:
        db_session.close()
        logger.info("--- Ingestion Pipeline Finished ---")


if __name__ == "__main__":
    logger.info("Application started.")
    
    # Ensure the database and tables are created before running the pipeline
    init_db()
    
    # Run the main processing function
    run_markdown_conversion_pipeline()
    
    logger.info("Application finished.")
# Out:
# /Users/vandnarajpal/Downloads/Cogstate-RFI/venv/lib/python3.13/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# 2025-07-22 11:32:09,248 - __main__ - INFO - Application started.
# 2025-07-22 11:32:09,249 - rfiprocessor.db.database - INFO - Initializing database and creating tables if they don't exist...
# 2025-07-22 11:32:09,252 - rfiprocessor.db.database - INFO - Database initialization complete.
# 2025-07-22 11:32:09,252 - __main__ - INFO - --- Starting Markdown Conversion Pipeline ---
# 2025-07-22 11:32:09,544 - rfiprocessor.services.llm_provider - INFO - Initialized Fast LLM Provider: gpt-4-turbo
# 2025-07-22 11:32:09,545 - rfiprocessor.services.prompt_loader - INFO - Loading prompt 'document_classifier' from: rfiprocessor/prompts/document_classifier.txt
# 2025-07-22 11:32:09,545 - rfiprocessor.core.agents.document_classifier - INFO - DocumentClassifierAgent initialized successfully.
# 2025-07-22 11:32:09,545 - rfiprocessor.utils.wlak_dir - DEBUG - Found file: data/raw/incoming/.DS_Store
# 2025-07-22 11:32:09,546 - rfiprocessor.utils.wlak_dir - DEBUG - Found file: data/raw/incoming/AbbVie/Copy of AbbVie Remediation Assessment- IT Security Privacy- Cogstate v10 (Additional Info) 3 Feb 2016.xlsx
# 2025-07-22 11:32:09,546 - rfiprocessor.utils.wlak_dir - DEBUG - Found file: data/raw/incoming/AbbVie/07 Nov 2023/Cogstate_RFI_AbbVie S&E Vendor Communication Plan.docx
# 2025-07-22 11:32:09,546 - rfiprocessor.utils.wlak_dir - DEBUG - Found file: data/raw/incoming/AbbVie/30 March 2016/Attachment 2.xlsx
# 2025-07-22 11:32:09,546 - rfiprocessor.utils.wlak_dir - DEBUG - Found file: data/raw/incoming/AbbVie/30 March 2016/Corporate Org Chart.pdf
# 2025-07-22 11:32:09,546 - rfiprocessor.utils.wlak_dir - DEBUG - Found file: data/raw/incoming/AbbVie/30 March 2016/Attachment 1 - ISO Certificate.pdf
# 2025-07-22 11:32:09,547 - rfiprocessor.utils.wlak_dir - DEBUG - Found file: data/raw/incoming/AbbVie/30 March 2016/Abbvie.pdf
# 2025-07-22 11:32:09,547 - rfiprocessor.utils.wlak_dir - DEBUG - Found file: data/raw/incoming/AbbVie/30 March 2016/AbbVie_Recruitment Survey_Cogstate 2016 -FINAL.doc
# 2025-07-22 11:32:09,547 - rfiprocessor.utils.wlak_dir - DEBUG - Found file: data/raw/incoming/Acadia/Acadia_CHDR_Ph1 Challenge_HV_CT_QualityQuestionnaire_SoftwareSupplier_28Jan2022_V1.0/Cogstate_Acadia_CHDR_Ph1 Challenge_HV_CT QualityQuestionnaire_SoftwareSupplier_28 Jan 2022_V1.0.pdf
# 2025-07-22 11:32:09,547 - rfiprocessor.utils.wlak_dir - DEBUG - Found file: data/raw/incoming/ADDF/ADDF ACCESS Request for Information.docx
# 2025-07-22 11:32:09,547 - __main__ - INFO - Found 10 files. Registering new files in the database...
# 2025-07-22 11:32:09,554 - rfiprocessor.services.db_handler - INFO - Added new document '.DS_Store' to database with ID 1.
# 2025-07-22 11:32:09,555 - rfiprocessor.services.db_handler - INFO - Added new document 'Copy of AbbVie Remediation Assessment- IT Security Privacy- Cogstate v10 (Additional Info) 3 Feb 2016.xlsx' to database with ID 2.
# 2025-07-22 11:32:09,556 - rfiprocessor.services.db_handler - INFO - Added new document 'Cogstate_RFI_AbbVie S&E Vendor Communication Plan.docx' to database with ID 3.
# 2025-07-22 11:32:09,557 - rfiprocessor.services.db_handler - INFO - Added new document 'Attachment 2.xlsx' to database with ID 4.
# 2025-07-22 11:32:09,558 - rfiprocessor.services.db_handler - INFO - Added new document 'Corporate Org Chart.pdf' to database with ID 5.
# 2025-07-22 11:32:09,561 - rfiprocessor.services.db_handler - INFO - Added new document 'Attachment 1 - ISO Certificate.pdf' to database with ID 6.
# 2025-07-22 11:32:09,566 - rfiprocessor.services.db_handler - INFO - Added new document 'Abbvie.pdf' to database with ID 7.
# 2025-07-22 11:32:09,569 - rfiprocessor.services.db_handler - INFO - Added new document 'AbbVie_Recruitment Survey_Cogstate 2016 -FINAL.doc' to database with ID 8.
# 2025-07-22 11:32:09,570 - rfiprocessor.services.db_handler - INFO - Added new document 'Cogstate_Acadia_CHDR_Ph1 Challenge_HV_CT QualityQuestionnaire_SoftwareSupplier_28 Jan 2022_V1.0.pdf' to database with ID 9.
# 2025-07-22 11:32:09,571 - rfiprocessor.services.db_handler - INFO - Added new document 'ADDF ACCESS Request for Information.docx' to database with ID 10.
# 2025-07-22 11:32:09,571 - rfiprocessor.services.db_handler - DEBUG - Querying for documents with status: PENDING
# 2025-07-22 11:32:09,572 - __main__ - INFO - Found 9 new documents to process.
# Converting files to Markdown:   0%|          | 0/9 [00:00<?, ?it/s]2025-07-22 11:32:09,588 - __main__ - INFO - Processing document: Copy of AbbVie Remediation Assessment- IT Security Privacy- Cogstate v10 (Additional Info) 3 Feb 2016.xlsx (ID: 2)
# 2025-07-22 11:32:09,589 - rfiprocessor.services.markdown_converter - INFO - Converting file: data/raw/incoming/AbbVie/Copy of AbbVie Remediation Assessment- IT Security Privacy- Cogstate v10 (Additional Info) 3 Feb 2016.xlsx with unstructured
# 2025-07-22 11:32:09,669 - rfiprocessor.services.markdown_converter - ERROR - Unstructured processing failed: No module named 'msoffcrypto'
# 2025-07-22 11:32:09,670 - rfiprocessor.services.markdown_converter - ERROR - Conversion failed: No module named 'msoffcrypto'
# 2025-07-22 11:32:09,670 - __main__ - ERROR - Error processing document ID 2 ('Copy of AbbVie Remediation Assessment- IT Security Privacy- Cogstate v10 (Additional Info) 3 Feb 2016.xlsx'): No module named 'msoffcrypto'
# Traceback (most recent call last):
#   File "/var/folders/cc/pdqst0z934d2c4blgp3h5jq00000gn/T/ipykernel_11079/3934356070.py", line 74, in run_markdown_conversion_pipeline
#     markdown_content, markdown_path = converter.convert_to_markdown(
#                                       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         file_path=doc.source_filepath,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         processor=processor_to_use
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/rfiprocessor/services/markdown_converter.py", line 46, in convert_to_markdown
#     markdown_content = self._process_with_unstructured(file_path)
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/rfiprocessor/services/markdown_converter.py", line 74, in _process_with_unstructured
#     elements = partition(file_path)
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/venv/lib/python3.13/site-packages/unstructured/partition/auto.py", line 291, in partition
#     partition = partitioner_loader.get(file_type)
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/venv/lib/python3.13/site-packages/unstructured/partition/auto.py", line 364, in get
#     self._partitioners[file_type] = self._load_partitioner(file_type)
#                                     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/venv/lib/python3.13/site-packages/unstructured/partition/auto.py", line 382, in _load_partitioner
#     partitioner_module = importlib.import_module(file_type.partitioner_module_qname)
#   File "/opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/importlib/__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 1026, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/venv/lib/python3.13/site-packages/unstructured/partition/xlsx.py", line 11, in <module>
#     from msoffcrypto import OfficeFile
# ModuleNotFoundError: No module named 'msoffcrypto'
# 2025-07-22 11:32:09,673 - rfiprocessor.services.db_handler - INFO - Updating document ID 2 with: {'ingestion_status': <IngestionStatus.FAILED: 'FAILED'>, 'error_message': "No module named 'msoffcrypto'"}
# 2025-07-22 11:32:09,674 - __main__ - INFO - Processing document: Cogstate_RFI_AbbVie S&E Vendor Communication Plan.docx (ID: 3)
# 2025-07-22 11:32:09,675 - rfiprocessor.services.markdown_converter - INFO - Converting file: data/raw/incoming/AbbVie/07 Nov 2023/Cogstate_RFI_AbbVie S&E Vendor Communication Plan.docx with markitdown
# 2025-07-22 11:32:09,994 - rfiprocessor.services.markdown_converter - INFO - Saved markdown to: data/markdown/incoming/Cogstate_RFI_AbbVie S&E Vendor Communication Plan.md
# 2025-07-22 11:32:09,995 - rfiprocessor.services.db_handler - INFO - Updating document ID 3 with: {'markdown_filepath': 'data/markdown/incoming/Cogstate_RFI_AbbVie S&E Vendor Communication Plan.md', 'processed_filepath': 'data/raw/processed/Cogstate_RFI_AbbVie S&E Vendor Communication Plan.docx', 'ingestion_status': <IngestionStatus.MARKDOWN_CONVERTED: 'MARKDOWN_CONVERTED'>, 'error_message': None}
# 2025-07-22 11:32:09,997 - __main__ - INFO - Successfully converted and moved document ID 3.
# Converting files to Markdown:  22%|██▏       | 2/9 [00:00<00:01,  4.90it/s]2025-07-22 11:32:09,997 - __main__ - INFO - Processing document: Attachment 2.xlsx (ID: 4)
# 2025-07-22 11:32:09,998 - rfiprocessor.services.markdown_converter - INFO - Converting file: data/raw/incoming/AbbVie/30 March 2016/Attachment 2.xlsx with unstructured
# 2025-07-22 11:32:09,999 - rfiprocessor.services.markdown_converter - ERROR - Unstructured processing failed: No module named 'msoffcrypto'
# 2025-07-22 11:32:09,999 - rfiprocessor.services.markdown_converter - ERROR - Conversion failed: No module named 'msoffcrypto'
# 2025-07-22 11:32:09,999 - __main__ - ERROR - Error processing document ID 4 ('Attachment 2.xlsx'): No module named 'msoffcrypto'
# Traceback (most recent call last):
#   File "/var/folders/cc/pdqst0z934d2c4blgp3h5jq00000gn/T/ipykernel_11079/3934356070.py", line 74, in run_markdown_conversion_pipeline
#     markdown_content, markdown_path = converter.convert_to_markdown(
#                                       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         file_path=doc.source_filepath,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         processor=processor_to_use
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/rfiprocessor/services/markdown_converter.py", line 46, in convert_to_markdown
#     markdown_content = self._process_with_unstructured(file_path)
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/rfiprocessor/services/markdown_converter.py", line 74, in _process_with_unstructured
#     elements = partition(file_path)
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/venv/lib/python3.13/site-packages/unstructured/partition/auto.py", line 291, in partition
#     partition = partitioner_loader.get(file_type)
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/venv/lib/python3.13/site-packages/unstructured/partition/auto.py", line 364, in get
#     self._partitioners[file_type] = self._load_partitioner(file_type)
#                                     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/venv/lib/python3.13/site-packages/unstructured/partition/auto.py", line 382, in _load_partitioner
#     partitioner_module = importlib.import_module(file_type.partitioner_module_qname)
#   File "/opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/importlib/__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 1026, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/venv/lib/python3.13/site-packages/unstructured/partition/xlsx.py", line 11, in <module>
#     from msoffcrypto import OfficeFile
# ModuleNotFoundError: No module named 'msoffcrypto'
# 2025-07-22 11:32:10,000 - rfiprocessor.services.db_handler - INFO - Updating document ID 4 with: {'ingestion_status': <IngestionStatus.FAILED: 'FAILED'>, 'error_message': "No module named 'msoffcrypto'"}
# 2025-07-22 11:32:10,001 - __main__ - INFO - Processing document: Corporate Org Chart.pdf (ID: 5)
# 2025-07-22 11:32:10,001 - rfiprocessor.services.markdown_converter - INFO - Converting file: data/raw/incoming/AbbVie/30 March 2016/Corporate Org Chart.pdf with markitdown
# 2025-07-22 11:32:10,008 - rfiprocessor.services.markdown_converter - INFO - Saved markdown to: data/markdown/incoming/Corporate Org Chart.md
# 2025-07-22 11:32:10,009 - rfiprocessor.services.db_handler - INFO - Updating document ID 5 with: {'markdown_filepath': 'data/markdown/incoming/Corporate Org Chart.md', 'processed_filepath': 'data/raw/processed/Corporate Org Chart.pdf', 'ingestion_status': <IngestionStatus.MARKDOWN_CONVERTED: 'MARKDOWN_CONVERTED'>, 'error_message': None}
# 2025-07-22 11:32:10,011 - __main__ - INFO - Successfully converted and moved document ID 5.
# 2025-07-22 11:32:10,011 - __main__ - INFO - Processing document: Attachment 1 - ISO Certificate.pdf (ID: 6)
# 2025-07-22 11:32:10,011 - rfiprocessor.services.markdown_converter - INFO - Converting file: data/raw/incoming/AbbVie/30 March 2016/Attachment 1 - ISO Certificate.pdf with markitdown
# The PDF <_io.BufferedReader name='data/raw/incoming/AbbVie/30 March 2016/Attachment 1 - ISO Certificate.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
# 2025-07-22 11:32:10,064 - rfiprocessor.services.markdown_converter - INFO - Saved markdown to: data/markdown/incoming/Attachment 1 - ISO Certificate.md
# 2025-07-22 11:32:10,064 - rfiprocessor.services.db_handler - INFO - Updating document ID 6 with: {'markdown_filepath': 'data/markdown/incoming/Attachment 1 - ISO Certificate.md', 'processed_filepath': 'data/raw/processed/Attachment 1 - ISO Certificate.pdf', 'ingestion_status': <IngestionStatus.MARKDOWN_CONVERTED: 'MARKDOWN_CONVERTED'>, 'error_message': None}
# 2025-07-22 11:32:10,066 - __main__ - INFO - Successfully converted and moved document ID 6.
# 2025-07-22 11:32:10,066 - __main__ - INFO - Processing document: Abbvie.pdf (ID: 7)
# 2025-07-22 11:32:10,066 - rfiprocessor.services.markdown_converter - INFO - Converting file: data/raw/incoming/AbbVie/30 March 2016/Abbvie.pdf with markitdown
# 2025-07-22 11:32:10,080 - rfiprocessor.services.markdown_converter - INFO - Saved markdown to: data/markdown/incoming/Abbvie.md
# 2025-07-22 11:32:10,081 - rfiprocessor.services.db_handler - INFO - Updating document ID 7 with: {'markdown_filepath': 'data/markdown/incoming/Abbvie.md', 'processed_filepath': 'data/raw/processed/Abbvie.pdf', 'ingestion_status': <IngestionStatus.MARKDOWN_CONVERTED: 'MARKDOWN_CONVERTED'>, 'error_message': None}
# 2025-07-22 11:32:10,082 - __main__ - INFO - Successfully converted and moved document ID 7.
# 2025-07-22 11:32:10,082 - __main__ - INFO - Processing document: AbbVie_Recruitment Survey_Cogstate 2016 -FINAL.doc (ID: 8)
# 2025-07-22 11:32:10,083 - rfiprocessor.services.markdown_converter - INFO - Converting file: data/raw/incoming/AbbVie/30 March 2016/AbbVie_Recruitment Survey_Cogstate 2016 -FINAL.doc with unstructured
# 2025-07-22 11:32:19,792 - rfiprocessor.services.markdown_converter - ERROR - Unstructured processing failed: soffice command was not found. Please install libreoffice
# on your system and try again.
#
# - Install instructions: https://www.libreoffice.org/get-help/install-howto/
# - Mac: https://formulae.brew.sh/cask/libreoffice
# - Debian: https://wiki.debian.org/LibreOffice
# 2025-07-22 11:32:19,793 - rfiprocessor.services.markdown_converter - ERROR - Conversion failed: soffice command was not found. Please install libreoffice
# on your system and try again.
#
# - Install instructions: https://www.libreoffice.org/get-help/install-howto/
# - Mac: https://formulae.brew.sh/cask/libreoffice
# - Debian: https://wiki.debian.org/LibreOffice
# 2025-07-22 11:32:19,793 - __main__ - ERROR - Error processing document ID 8 ('AbbVie_Recruitment Survey_Cogstate 2016 -FINAL.doc'): soffice command was not found. Please install libreoffice
# on your system and try again.
#
# - Install instructions: https://www.libreoffice.org/get-help/install-howto/
# - Mac: https://formulae.brew.sh/cask/libreoffice
# - Debian: https://wiki.debian.org/LibreOffice
# Traceback (most recent call last):
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/venv/lib/python3.13/site-packages/unstructured/partition/common/common.py", line 298, in convert_office_doc
#     output = subprocess.run(command, capture_output=True)
#   File "/opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/subprocess.py", line 1039, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         pass_fds, cwd, env,
#                         ^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#                         gid, gids, uid, umask,
#                         ^^^^^^^^^^^^^^^^^^^^^^
#                         start_new_session, process_group)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/subprocess.py", line 1972, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'soffice'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/var/folders/cc/pdqst0z934d2c4blgp3h5jq00000gn/T/ipykernel_11079/3934356070.py", line 74, in run_markdown_conversion_pipeline
#     markdown_content, markdown_path = converter.convert_to_markdown(
#                                       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         file_path=doc.source_filepath,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         processor=processor_to_use
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/rfiprocessor/services/markdown_converter.py", line 46, in convert_to_markdown
#     markdown_content = self._process_with_unstructured(file_path)
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/rfiprocessor/services/markdown_converter.py", line 74, in _process_with_unstructured
#     elements = partition(file_path)
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/venv/lib/python3.13/site-packages/unstructured/partition/auto.py", line 292, in partition
#     elements = partition(filename=filename, file=file, **partitioning_kwargs)
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/venv/lib/python3.13/site-packages/unstructured/partition/doc.py", line 74, in partition_doc
#     convert_office_doc(
#     ~~~~~~~~~~~~~~~~~~^
#         source_file_path,
#         ^^^^^^^^^^^^^^^^^
#     ...<2 lines>...
#         target_filter=libre_office_filter,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/vandnarajpal/Downloads/Cogstate-RFI/venv/lib/python3.13/site-packages/unstructured/partition/common/common.py", line 311, in convert_office_doc
#             raise FileNotFoundError(
#     ...<6 lines>...
#             )
# FileNotFoundError: soffice command was not found. Please install libreoffice
# on your system and try again.
#
# - Install instructions: https://www.libreoffice.org/get-help/install-howto/
# - Mac: https://formulae.brew.sh/cask/libreoffice
# - Debian: https://wiki.debian.org/LibreOffice
# 2025-07-22 11:32:19,797 - rfiprocessor.services.db_handler - INFO - Updating document ID 8 with: {'ingestion_status': <IngestionStatus.FAILED: 'FAILED'>, 'error_message': 'soffice command was not found. Please install libreoffice\non your system and try again.\n\n- Install instructions: https://www.libreoffice.org/get-help/install-howto/\n- Mac: https://formulae.brew.sh/cask/libreoffice\n- Debian: https://wiki.debian.org/LibreOffice'}
# Converting files to Markdown:  78%|███████▊  | 7/9 [00:10<00:03,  1.58s/it]2025-07-22 11:32:19,798 - __main__ - INFO - Processing document: Cogstate_Acadia_CHDR_Ph1 Challenge_HV_CT QualityQuestionnaire_SoftwareSupplier_28 Jan 2022_V1.0.pdf (ID: 9)
# 2025-07-22 11:32:19,799 - rfiprocessor.services.markdown_converter - INFO - Converting file: data/raw/incoming/Acadia/Acadia_CHDR_Ph1 Challenge_HV_CT_QualityQuestionnaire_SoftwareSupplier_28Jan2022_V1.0/Cogstate_Acadia_CHDR_Ph1 Challenge_HV_CT QualityQuestionnaire_SoftwareSupplier_28 Jan 2022_V1.0.pdf with markitdown
# 2025-07-22 11:32:21,198 - rfiprocessor.services.markdown_converter - INFO - Saved markdown to: data/markdown/incoming/Cogstate_Acadia_CHDR_Ph1 Challenge_HV_CT QualityQuestionnaire_SoftwareSupplier_28 Jan 2022_V1.0.md
# 2025-07-22 11:32:21,199 - rfiprocessor.services.db_handler - INFO - Updating document ID 9 with: {'markdown_filepath': 'data/markdown/incoming/Cogstate_Acadia_CHDR_Ph1 Challenge_HV_CT QualityQuestionnaire_SoftwareSupplier_28 Jan 2022_V1.0.md', 'processed_filepath': 'data/raw/processed/Cogstate_Acadia_CHDR_Ph1 Challenge_HV_CT QualityQuestionnaire_SoftwareSupplier_28 Jan 2022_V1.0.pdf', 'ingestion_status': <IngestionStatus.MARKDOWN_CONVERTED: 'MARKDOWN_CONVERTED'>, 'error_message': None}
# 2025-07-22 11:32:21,200 - __main__ - INFO - Successfully converted and moved document ID 9.
# Converting files to Markdown:  89%|████████▉ | 8/9 [00:11<00:01,  1.54s/it]2025-07-22 11:32:21,201 - __main__ - INFO - Processing document: ADDF ACCESS Request for Information.docx (ID: 10)
# 2025-07-22 11:32:21,201 - rfiprocessor.services.markdown_converter - INFO - Converting file: data/raw/incoming/ADDF/ADDF ACCESS Request for Information.docx with markitdown
# 2025-07-22 11:32:21,578 - rfiprocessor.services.markdown_converter - INFO - Saved markdown to: data/markdown/incoming/ADDF ACCESS Request for Information.md
# 2025-07-22 11:32:21,579 - rfiprocessor.services.db_handler - INFO - Updating document ID 10 with: {'markdown_filepath': 'data/markdown/incoming/ADDF ACCESS Request for Information.md', 'processed_filepath': 'data/raw/processed/ADDF ACCESS Request for Information.docx', 'ingestion_status': <IngestionStatus.MARKDOWN_CONVERTED: 'MARKDOWN_CONVERTED'>, 'error_message': None}
# 2025-07-22 11:32:21,580 - __main__ - INFO - Successfully converted and moved document ID 10.
# Converting files to Markdown: 100%|██████████| 9/9 [00:11<00:00,  1.33s/it]
# 2025-07-22 11:32:21,581 - __main__ - INFO - --- Markdown Conversion Pipeline Finished ---
# 2025-07-22 11:32:21,581 - __main__ - INFO - --- Starting Document Classification Step ---
# 2025-07-22 11:32:21,581 - rfiprocessor.services.db_handler - DEBUG - Querying for documents with status: MARKDOWN_CONVERTED
# 2025-07-22 11:32:21,582 - __main__ - INFO - Found 6 documents to classify.
# Classifying documents:   0%|          | 0/6 [00:00<?, ?it/s]2025-07-22 11:32:21,582 - __main__ - INFO - Classifying document: Cogstate_RFI_AbbVie S&E Vendor Communication Plan.docx (ID: 3)
# 2025-07-22 11:32:21,583 - rfiprocessor.core.agents.document_classifier - INFO - Attempting to classify document...
# 2025-07-22 11:32:24,293 - rfiprocessor.core.agents.document_classifier - DEBUG - LLM raw response for classification: {
#   "document_type": "RFI/RFP",
#   "document_grade": "Past Response"
# }
# 2025-07-22 11:32:24,294 - rfiprocessor.core.agents.document_classifier - INFO - Document classified successfully as: {'document_type': 'RFI/RFP', 'document_grade': 'Past Response'}
# 2025-07-22 11:32:24,296 - rfiprocessor.services.db_handler - INFO - Updating document ID 3 with: {'document_type': 'RFI/RFP', 'document_grade': 'Past Response', 'ingestion_status': <IngestionStatus.CLASSIFIED: 'CLASSIFIED'>, 'error_message': None}
# 2025-07-22 11:32:24,299 - __main__ - INFO - Successfully classified document ID 3.
# Classifying documents:  17%|█▋        | 1/6 [00:02<00:13,  2.72s/it]2025-07-22 11:32:24,302 - __main__ - INFO - Classifying document: Corporate Org Chart.pdf (ID: 5)
# 2025-07-22 11:32:24,303 - rfiprocessor.core.agents.document_classifier - INFO - Attempting to classify document...
# 2025-07-22 11:32:26,229 - rfiprocessor.core.agents.document_classifier - DEBUG - LLM raw response for classification: {
#   "document_type": "Supporting Document",
#   "document_grade": "General"
# }
# 2025-07-22 11:32:26,230 - rfiprocessor.core.agents.document_classifier - INFO - Document classified successfully as: {'document_type': 'Supporting Document', 'document_grade': 'General'}
# 2025-07-22 11:32:26,232 - rfiprocessor.services.db_handler - INFO - Updating document ID 5 with: {'document_type': 'Supporting Document', 'document_grade': 'General', 'ingestion_status': <IngestionStatus.CLASSIFIED: 'CLASSIFIED'>, 'error_message': None}
# 2025-07-22 11:32:26,235 - __main__ - INFO - Successfully classified document ID 5.
# Classifying documents:  33%|███▎      | 2/6 [00:04<00:09,  2.26s/it]2025-07-22 11:32:26,237 - __main__ - INFO - Classifying document: Attachment 1 - ISO Certificate.pdf (ID: 6)
# 2025-07-22 11:32:26,238 - rfiprocessor.core.agents.document_classifier - INFO - Attempting to classify document...
# 2025-07-22 11:32:28,790 - rfiprocessor.core.agents.document_classifier - DEBUG - LLM raw response for classification: {
#   "document_type": "Supporting Document",
#   "document_grade": "Regulatory Guideline"
# }
# 2025-07-22 11:32:28,791 - rfiprocessor.core.agents.document_classifier - INFO - Document classified successfully as: {'document_type': 'Supporting Document', 'document_grade': 'Regulatory Guideline'}
# 2025-07-22 11:32:28,793 - rfiprocessor.services.db_handler - INFO - Updating document ID 6 with: {'document_type': 'Supporting Document', 'document_grade': 'Regulatory Guideline', 'ingestion_status': <IngestionStatus.CLASSIFIED: 'CLASSIFIED'>, 'error_message': None}
# 2025-07-22 11:32:28,797 - __main__ - INFO - Successfully classified document ID 6.
# Classifying documents:  50%|█████     | 3/6 [00:07<00:07,  2.40s/it]2025-07-22 11:32:28,799 - __main__ - INFO - Classifying document: Abbvie.pdf (ID: 7)
# 2025-07-22 11:32:28,800 - rfiprocessor.core.agents.document_classifier - INFO - Attempting to classify document...
# 2025-07-22 11:32:30,471 - rfiprocessor.core.agents.document_classifier - DEBUG - LLM raw response for classification: {
#   "document_type": "Supporting Document",
#   "document_grade": "General"
# }
# 2025-07-22 11:32:30,473 - rfiprocessor.core.agents.document_classifier - INFO - Document classified successfully as: {'document_type': 'Supporting Document', 'document_grade': 'General'}
# 2025-07-22 11:32:30,475 - rfiprocessor.services.db_handler - INFO - Updating document ID 7 with: {'document_type': 'Supporting Document', 'document_grade': 'General', 'ingestion_status': <IngestionStatus.CLASSIFIED: 'CLASSIFIED'>, 'error_message': None}
# 2025-07-22 11:32:30,480 - __main__ - INFO - Successfully classified document ID 7.
# Classifying documents:  67%|██████▋   | 4/6 [00:08<00:04,  2.11s/it]2025-07-22 11:32:30,482 - __main__ - INFO - Classifying document: Cogstate_Acadia_CHDR_Ph1 Challenge_HV_CT QualityQuestionnaire_SoftwareSupplier_28 Jan 2022_V1.0.pdf (ID: 9)
# 2025-07-22 11:32:30,484 - rfiprocessor.core.agents.document_classifier - INFO - Attempting to classify document...
# 2025-07-22 11:32:32,272 - rfiprocessor.core.agents.document_classifier - DEBUG - LLM raw response for classification: {
#   "document_type": "RFI/RFP",
#   "document_grade": "Past Response"
# }
# 2025-07-22 11:32:32,273 - rfiprocessor.core.agents.document_classifier - INFO - Document classified successfully as: {'document_type': 'RFI/RFP', 'document_grade': 'Past Response'}
# 2025-07-22 11:32:32,275 - rfiprocessor.services.db_handler - INFO - Updating document ID 9 with: {'document_type': 'RFI/RFP', 'document_grade': 'Past Response', 'ingestion_status': <IngestionStatus.CLASSIFIED: 'CLASSIFIED'>, 'error_message': None}
# 2025-07-22 11:32:32,280 - __main__ - INFO - Successfully classified document ID 9.
# Classifying documents:  83%|████████▎ | 5/6 [00:10<00:02,  2.00s/it]2025-07-22 11:32:32,282 - __main__ - INFO - Classifying document: ADDF ACCESS Request for Information.docx (ID: 10)
# 2025-07-22 11:32:32,283 - rfiprocessor.core.agents.document_classifier - INFO - Attempting to classify document...
# 2025-07-22 11:32:34,627 - rfiprocessor.core.agents.document_classifier - DEBUG - LLM raw response for classification: {
#   "document_type": "RFI/RFP",
#   "document_grade": "Past Response"
# }
# 2025-07-22 11:32:34,628 - rfiprocessor.core.agents.document_classifier - INFO - Document classified successfully as: {'document_type': 'RFI/RFP', 'document_grade': 'Past Response'}
# 2025-07-22 11:32:34,631 - rfiprocessor.services.db_handler - INFO - Updating document ID 10 with: {'document_type': 'RFI/RFP', 'document_grade': 'Past Response', 'ingestion_status': <IngestionStatus.CLASSIFIED: 'CLASSIFIED'>, 'error_message': None}
# 2025-07-22 11:32:34,635 - __main__ - INFO - Successfully classified document ID 10.
# Classifying documents: 100%|██████████| 6/6 [00:13<00:00,  2.18s/it]
# 2025-07-22 11:32:34,638 - __main__ - INFO - --- Ingestion Pipeline Finished ---
# 2025-07-22 11:32:34,638 - __main__ - INFO - Application finished.

# %%
from tqdm import tqdm

# --- Core Application Imports ---
from config.config import Config
from rfiprocessor.utils.logger import get_logger
from rfiprocessor.core.agents.document_classifier import DocumentClassifierAgent

# --- Database Imports ---
from rfiprocessor.db.database import init_db, get_db_session
from rfiprocessor.services.db_handler import DatabaseHandler
from rfiprocessor.db.db_models import IngestionStatus

# --- Initial Setup ---
config = Config()
logger = get_logger(__name__)

def run_document_classification_pipeline():
    """
    Scans for markdown_converted files, classify them to RFI/RFO or Supporting Document with grades, and tracks progress in the database.
    """

    classifier = DocumentClassifierAgent()

    # Get a database session and initialize the handler
    db_session_generator = get_db_session()
    db_session = next(db_session_generator)
    try:
        db_handler = DatabaseHandler(db_session)

        # --- Step 2: Document Classification ---
        logger.info("--- Starting Document Classification Step ---")
        docs_to_classify = db_handler.get_documents_by_status(IngestionStatus.MARKDOWN_CONVERTED)

        if not docs_to_classify:
            logger.info("No new documents to classify.")
        else:
            logger.info(f"Found {len(docs_to_classify)} documents to classify.")

        for doc in tqdm(docs_to_classify, desc="Classifying documents"):
            try:
                logger.info(f"Classifying document: {doc.source_filename} (ID: {doc.id})")
                
                # Read the markdown content from the file
                with open(doc.markdown_filepath, 'r', encoding='utf-8') as f:
                    markdown_content = f.read()
                
                # Call the classifier agent
                classification = classifier.classify(markdown_content)
                
                # Update the document in the database
                updates = {
                    "document_type": classification.get("document_type"),
                    "document_grade": classification.get("document_grade"),
                    "ingestion_status": IngestionStatus.CLASSIFIED,
                    "error_message": None
                }
                db_handler.update_document(doc.id, updates)
                logger.info(f"Successfully classified document ID {doc.id}.")

            except Exception as e:
                logger.error(f"Error classifying document ID {doc.id}: {e}", exc_info=True)
                db_handler.update_document(
                    doc.id,
                    {"ingestion_status": IngestionStatus.FAILED, "error_message": f"Classification failed: {e}"}
                )

    finally:
        db_session.close()
        logger.info("--- Ingestion Pipeline Finished ---")

if __name__ == "__main__":
    logger.info("Application started.")
    
    # Ensure the database and tables are created before running the pipeline
    init_db()
    
    # Run the main processing function
    run_document_classification_pipeline()
    
    logger.info("Application finished.")
# Out:
# 2025-07-22 11:32:34,651 - __main__ - INFO - Application started.
# 2025-07-22 11:32:34,652 - rfiprocessor.db.database - INFO - Initializing database and creating tables if they don't exist...
# 2025-07-22 11:32:34,654 - rfiprocessor.db.database - INFO - Database initialization complete.
# 2025-07-22 11:32:34,655 - rfiprocessor.services.llm_provider - INFO - Initialized Fast LLM Provider: gpt-4-turbo
# 2025-07-22 11:32:34,655 - rfiprocessor.services.prompt_loader - DEBUG - Returning cached prompt: 'document_classifier'
# 2025-07-22 11:32:34,656 - rfiprocessor.core.agents.document_classifier - INFO - DocumentClassifierAgent initialized successfully.
# 2025-07-22 11:32:34,657 - __main__ - INFO - --- Starting Document Classification Step ---
# 2025-07-22 11:32:34,658 - rfiprocessor.services.db_handler - DEBUG - Querying for documents with status: MARKDOWN_CONVERTED
# 2025-07-22 11:32:34,659 - __main__ - INFO - No new documents to classify.
# Classifying documents: 0it [00:00, ?it/s]
# 2025-07-22 11:32:34,661 - __main__ - INFO - --- Ingestion Pipeline Finished ---
# 2025-07-22 11:32:34,661 - __main__ - INFO - Application finished.

# %%
from tqdm import tqdm
from pydantic import ValidationError

# --- Core Application Imports ---
from config.config import Config
from rfiprocessor.utils.logger import get_logger
from rfiprocessor.core.agents.rfi_parser import RfiParserAgent

# --- Database Imports ---
from rfiprocessor.db.database import init_db, get_db_session
from rfiprocessor.services.db_handler import DatabaseHandler
from rfiprocessor.db.db_models import IngestionStatus
from rfiprocessor.models.data_models import RFIJson

import os
import json

# --- Initial Setup ---
config = Config()
logger = get_logger(__name__)

def run_rfi_parser_pipeline():
    """
    Scans for classified RFI/RFP files and processes them through the RFI parser pipeline.
    """
    logger.info("--- Starting RFI Parsing Pipeline ---")
    rfi_parser = RfiParserAgent()
    
    db_session_generator = get_db_session()
    db_session = next(db_session_generator)
    try:
        db_handler = DatabaseHandler(db_session)

        # --- Step 3: RFI/RFP Parsing ---
        logger.info("--- Starting RFI/RFP Parsing Step ---")
        docs_to_parse = db_handler.get_documents_by_status(IngestionStatus.CLASSIFIED)

        if not docs_to_parse:
            logger.info("No new classified documents to parse.")
        else:
            logger.info(f"Found {len(docs_to_parse)} documents to potentially parse.")

        for doc in tqdm(docs_to_parse, desc="Parsing RFI/RFP documents"):
            try:
                # Only process documents that were classified as RFI/RFP
                if doc.document_type != "RFI/RFP":
                    logger.info(f"Skipping parsing for doc ID {doc.id} (type: {doc.document_type}). Marking as parsed.")
                    db_handler.update_document(doc.id, {"ingestion_status": IngestionStatus.PARSED})
                    continue

                logger.info(f"Parsing RFI/RFP document: {doc.source_filename} (ID: {doc.id})")
                
                # Read the markdown content
                with open(doc.markdown_filepath, 'r', encoding='utf-8') as f:
                    markdown_content = f.read()
                
                # Call the RFI Parser Agent
                parsed_data = rfi_parser.parse(markdown_content)
                
                # --- SAVE TO /json_output FOLDER AT PROJECT ROOT ---
                output_dir = "json_output"
                os.makedirs(output_dir, exist_ok=True)
                json_filename = os.path.splitext(doc.source_filename)[0] + ".json"
                output_path = os.path.join(output_dir, json_filename)
                with open(output_path, "w", encoding="utf-8") as f:
                    json.dump(parsed_data, f, indent=2, ensure_ascii=False)
                logger.info(f"Saved parsed output to {output_path}")
                # --- END SAVE SECTION ---

                # Validate the structured output with Pydantic
                try:
                    validated_data = RFIJson.model_validate(parsed_data)
                    logger.info(f"Successfully validated JSON structure for doc ID {doc.id}.")
                except ValidationError as ve:
                    # If validation fails, log the specific error and mark the doc as failed
                    error_details = f"Pydantic validation failed for doc ID {doc.id}: {ve}"
                    logger.error(error_details)
                    db_handler.update_document(
                        doc.id,
                        {"ingestion_status": IngestionStatus.FAILED, "error_message": error_details}
                    )
                    continue  # Skip to the next document
                
                # Update the document record with the JSON payload and new status
                updates = {
                    "rfi_json_payload": validated_data.model_dump(),  # Use the validated data
                    "ingestion_status": IngestionStatus.PARSED,
                    "error_message": None
                }
                db_handler.update_document(doc.id, updates)
                logger.info(f"Successfully parsed and stored JSON for document ID {doc.id}.")

            except Exception as e:
                error_msg = f"Error parsing document ID {doc.id}: {e}"
                logger.error(error_msg, exc_info=True)
                db_handler.update_document(
                    doc.id,
                    {"ingestion_status": IngestionStatus.FAILED, "error_message": error_msg}
                )

    finally:
        db_session.close()
        logger.info("--- Ingestion Pipeline Finished ---")

# The if __name__ == "__main__": block remains the same
if __name__ == "__main__":
    logger.info("Application started.")
    init_db()
    run_rfi_parser_pipeline()
    logger.info("Application finished.")
# Out:
# 2025-07-22 11:32:34,674 - __main__ - INFO - Application started.
# 2025-07-22 11:32:34,674 - rfiprocessor.db.database - INFO - Initializing database and creating tables if they don't exist...
# 2025-07-22 11:32:34,675 - rfiprocessor.db.database - INFO - Database initialization complete.
# 2025-07-22 11:32:34,675 - __main__ - INFO - --- Starting RFI Parsing Pipeline ---
# 2025-07-22 11:32:34,687 - rfiprocessor.services.llm_provider - INFO - Initialized Advanced LLM Provider: gpt-4o
# 2025-07-22 11:32:34,687 - rfiprocessor.services.prompt_loader - INFO - Loading prompt 'rfi_parser_summary' from: rfiprocessor/prompts/rfi_parser_summary.txt
# 2025-07-22 11:32:34,688 - rfiprocessor.services.prompt_loader - INFO - Loading prompt 'rfi_parser_chunking' from: rfiprocessor/prompts/rfi_parser_chunking.txt
# 2025-07-22 11:32:34,688 - rfiprocessor.core.agents.rfi_parser - INFO - RfiParserAgent initialized successfully.
# 2025-07-22 11:32:34,688 - __main__ - INFO - --- Starting RFI/RFP Parsing Step ---
# 2025-07-22 11:32:34,689 - rfiprocessor.services.db_handler - DEBUG - Querying for documents with status: CLASSIFIED
# 2025-07-22 11:32:34,689 - __main__ - INFO - Found 6 documents to potentially parse.
# Parsing RFI/RFP documents:   0%|          | 0/6 [00:00<?, ?it/s]2025-07-22 11:32:34,690 - __main__ - INFO - Parsing RFI/RFP document: Cogstate_RFI_AbbVie S&E Vendor Communication Plan.docx (ID: 3)
# 2025-07-22 11:32:34,690 - rfiprocessor.core.agents.rfi_parser - INFO - Generating executive summary...
# 2025-07-22 11:32:46,507 - rfiprocessor.core.agents.rfi_parser - INFO - Splitting document into processable chunks...
# 2025-07-22 11:32:46,508 - rfiprocessor.core.agents.rfi_parser - INFO - Processing 9 chunks concurrently...
# 2025-07-22 11:32:46,509 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# **hiS&E Vendor Communication Plan**
#
# |  |  |
# | --- | --- |
# | **Vendor Name** | **Cogstate, Inc.** |
# | **Vendor Point of Contact** | **George Waidell**  **Business Development Director**  **gwaidell@cogstate.com** |
#
# 1. **Evidence Breakdown**
#
# |  |  |  |
# | --- | --- | --- |
# | **Evidence Breakdown** | | |
# | **Category** | **Questions/ Subject** | **S&E Responses** |
# | 1. **V3: Verification, Analytical Validation, and Clinical Validation** | * ***Please provide documentation for:***    + ***Performance specifications for the integrated hardware***   + ***Output data specifications***   + ***Overview of software system tests***   + ***Limitations to the verification testing – e.g. specific known items that were not tested during verifications*** | ***With Cogstate digital cognitive testing solutions or rater training solutions, Cogstate can adapt to different types of hardware, so long as they meet requirements on our minimum requirements list. Cogstate can also adapt our data outputs to m...
# --- END OF CHUNK ---
#
# 2025-07-22 11:32:46,510 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# Studies*** | **None** |
# | * ***Awards*** | **In 2020 Cogstate was awarded a Digital Biomarker Award from Alzheimer’s Drug Discovery Foundation (ADDF).** |
# | * ***Partnerships in the Industry*** | **Cogstate has partnerships with several eCOA companies, including Clario and Clinical Ink. However we can work with AbbVie to find the suitable eCOA vendor for a study, if needed.** |
#
# 1. **Regulatory**
#
# |  |  |  |
# | --- | --- | --- |
# | **Regulatory** | | |
# | **Category** | **Questions/ Subject** | **S&E Responses** |
# | 1. **Compliance** | ***HIPAA Compliance*** | ***Yes. While Cogstate is not a covered entity, Cogstate has established several policies for ensuring data security compliance with HIPAA.*** |
# | ***GDPR Compliance*** | ***Yes. While Cogstate is not a covered entity, Cogstate has established several policies for ensuring data security compliance with GDPR.*** |
# | ***21 CFR Part 11 Compliance*** | ***Yes. While Cogstate is not a covered entity, Cogstate has established several poli...
# --- END OF CHUNK ---
#
# 2025-07-22 11:32:46,510 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# w data/client PII is handled.***  ***All data is encrypted in-transit and at rest. Cogstate utilizes AES 256 bit encryption for data at rest (both active and backup), and the latest TLS encryption for data in transit.***  ***Dependent upon the services provided by Cogstate in a study, the Cogstate Data Manager will discuss and agree with Sponsor on the format of data to be transferred, the schedule of transfers, the quality checks to be performed, and the process for query resolution. These details will be reflected in a data management plan.*** |
# | ***Is the data uploaded in “real-time” into the software?***   * *Data should be retrieved from the technology/sensor as soon as possible* | ***If connected to internet, the data is uploaded to the server throughout the assessment and routed back into the database CRFs after the processed outcomes are computed (which happen within a few minutes of the battery administration). If the device loses internet access partway through the assessmen...
# --- END OF CHUNK ---
#
# 2025-07-22 11:32:46,510 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
#  ***Does the DHT require any third-party data sources or integrations?*** | ***This would be dependent upon the type of services Cogstate is providing and that AbbVie is needing for its study.*** |
# | ***Will data be encrypted at risk or at rest?*** | ***Cogstate utilizes AES 256 bit encryption for data at rest (both active and backup), and the latest TLS encryption for data in transit.*** |
# | ***How is missing data handled?*** | ***Cogstate’s data management team will issue a query about the missing data, or other data discrepancies.*** |
# | ***Example of standard reports provided to sponsors*** | ***Data reports can be dependent upon the sponsor and their needs. Examples include: monthly “unclean” interim data transfers of computerized digital data. For the “unclean” interim transfers, the data will likely contain unresolved queries. Data files are always cumulative, containing all data, including resolved queries and unresolved queries.*** |
# | ***Is more granular level data available ...
# --- END OF CHUNK ---
#
# 2025-07-22 11:32:46,510 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# n dashboard updated real-time, etc)* | ***Yes, dashboards can be made available.***  ***The specifics of the dashboard will be determined by the needs of the study.*** |
# | ***How will subject information appear in the software*** *(i.e., coded by subject number)?* | ***For digital cognitive tests, it will be coded by subject number and visit number.*** |
# | ***How is the software accessed*** *(i.e., web-based, downloaded onto equipment etc.)?* | ***This depends on the type of services provided by Cogstate.*** |
# | ***Hardware storage capacity*** | ***The type of hardware is dependent upon the services provided, the type of hardware, and timelines available.*** |
# | ***Versions of hardware of software available*** *(e.g consumer vs. research)****?*** | ***This depends on the type of services provided by Cogstate.*** |
# | ***Any risks associated with versioning*** *(modification to hardware/software)****?*** | ***No*** |
# | ***Is a log maintained of who accesses the data server and when?*** |...
# --- END OF CHUNK ---
#
# 2025-07-22 11:32:46,511 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# **Questions/ Subject** | **S&E Responses** |
# | 1. **Industry** | ***Top competitors***   * *What differentiates you from your competitors?* | ***We are continually innovating, with a focus on ensuring we have superior digital cognitive testing available across a range of modalities that can be used in a range of settings. Our science team is actively engaged with the industry, regularly evaluating market developments and trends. We regularly scan the market for new entrants or developments within existing competitors. We have close relationships with major customers, ensuring that we understand their current and future needs and adapt our offering to meet those needs (for example, delivery of fully remote clinical trials).*** |
# | ***What are the main challenges that you face in your industry?***   * *What are the biggest opportunities?* | ***Cogstate provides proprietary digital brain health assessments along with scientific and operational expertise in respect of the assessment of cog...
# --- END OF CHUNK ---
#
# 2025-07-22 11:32:46,511 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# t to have a MSA in place in the first half of 2024.*** |
# | ***Studies*** | ***Costate is currently providing services on two Alzheimer’s studies: M23-515 and M22-721.*** |
# | ***Services*** | ***Cogstate provides Computerized Cognitive Testing, Rater Training, Central Monitoring, and Scientific Consulting in the active studies listed above.*** |
# | ***AbbVie portfolio*** | ***Costate is currently providing services on two Alzheimer’s studies: M23-515 and M22-721. We look forward to working with AbbVie on future studies.*** |
# | 1. **Growth Strategy** | ***Short-term and long-term strategies for growth*** | Cogstate Growth Strategies Include:  1. Market Penetration: Focus on strong delivery to customers to grow within accounts to support existing products/services including market leading digital cognitive testing solutions and data quality assurance services for conventional cognitive assessments such as rater training, certifications, monitoring and remediation.  2. Product/Service Innov...
# --- END OF CHUNK ---
#
# 2025-07-22 11:32:46,511 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
#  ensuring every employee understands their role in maintaining security and quality standards. This cultural shift is vital for fostering an environment where security is a continuous, evolving process, adapting to new challenges as the company grows.  Furthermore, our approach to scaling includes robust Disaster Recovery and Business Continuity plans. These plans ensure minimal operational disruption and quick recovery in the face of incidents ranging from cyber-attacks to natural disasters. This planning is integral to our commitment to maintain seamless service and protect our client’s data, regardless of unforeseen challenges.  Through these comprehensive strategies, Cogstate is dedicated to maintaining a high level of security and quality, ensuring resilience and adaptability as our business expands. |
# | 1. **Financial Health** | ***Provide financial information*** *(i.e past three years of audited financial statements including their income statement and balance sheet)* | ***For ...
# --- END OF CHUNK ---
#
# 2025-07-22 11:32:46,511 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# can manage all translations requested, depending upon the services provided.*** |
# | ***List of languages available*** | ***Please see above.*** |
# | 1. **Training** | ***Onboarding process for users*** | ***Cogstate aims to make the onboarding process for all users as simple as possible.*** |
# | 1. **Helpdesk Support** | **Does the company provide helpdesk support?** | ***Yes, Cogstate can provide helpdesk support.*** |
# | 1. **Specifics on the Technology** | ***If wearable:***   * *How is the technology worn?* * *Duration of “daily wearing”* * *Comfort* * *Material*   + *Device required to be labeled as containing natural rubber latex or dry natural rubber (21 CFR 801.437)*   + *Device labeled as "Not made with natural rubber latex"* * *Durability* * *Temperature sensitivity*   *Storage and Handling* | ***N/A*** |
# | ***If smartphone app:***   * *impact on smartphone battery* * *required use to capture data* | ***N/A*** |
#
# |  |  |
# | --- | --- |
# | **Additional Notes** | |
# |  |  |
# --- END OF CHUNK ---
#
# 2025-07-22 11:32:53,018 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': '', 'description': 'can manage all translations requested, depending upon the services provided.', 'qa_pairs': [{'question': 'List of languages available', 'answer': 'Please see above.', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Onboarding process for users', 'answer': 'Cogstate aims to make the onboarding process for all users as simple as possible.', 'domain': 'Support', 'type': 'open-ended'}, {'question': 'Does the company provide helpdesk support?', 'answer': 'Yes, Cogstate can provide helpdesk support.', 'domain': 'Support', 'type': 'close-ended'}, {'question': 'If wearable: How is the technology worn? Duration of “daily wearing” Comfort Material Device required to be labeled as containing natural rubber latex or dry natural rubber (21 CFR 801.437) Device labeled as "Not made with natural rubber latex" Durability Temperature sensitivity Storage and Handling', 'answer': 'N/A', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'If smartphone app: impact on smartphone battery required use to capture data', 'answer': 'N/A', 'domain': 'Technology', 'type': 'open-ended'}], 'meta_data': {'company_name': 'Cogstate', 'date': 'N/A', 'category': 'RFP', 'type': 'PastResponse'}}
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 11:32:58,968 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': 'Costate is currently providing services on two Alzheimer’s studies: M23-515 and M22-721.', 'description': 'Cogstate provides Computerized Cognitive Testing, Rater Training, Central Monitoring, and Scientific Consulting in the active studies listed above. Cogstate Growth Strategies Include: 1. Market Penetration: Focus on strong delivery to customers to grow within accounts to support existing products/services including market leading digital cognitive testing solutions and data quality assurance services for conventional cognitive assessments such as rater training, certifications, monitoring and remediation. 2. Product/Service Innovation: Introduce enhanced and complementary products/services to the existing portfolio, including additional data analytics capabilities leveraging recent investments in data lake infrastructure, as well as more scalable automated approaches to training, certification and monitoring--and in additional indications across neurology and psychiatry. 3. Market Development: Expand customer segment of computerized cognitive testing in healthcare as the introduction of disease modifying therapies increase unmet need for early-detection of cognitive change. 4. Partnerships and Alliances: Form additional strategic alliances and partnerships with CRO and eCOA providers to offer fit-for-purpose solutions to address the needs of different clinical trial programs. 5. Customer Retention: Prioritize customer satisfaction and loyalty initiatives to retain existing customers and encourage repeat business.', 'qa_pairs': [{'question': 'How do you plan to scale your resources for new businesses?', 'answer': 'Cogstate assesses market conditions, plans, and allocates financial, human, and technological resources in line with strategic growth objectives. As part of this we invest in scalable technology and systems, optimize operations for efficiency, and develop stepwise market entry and risk mitigation strategies.', 'domain': 'General', 'type': 'open-ended'}, {'question': 'How is your security and quality infrastructure going to scale with added business?', 'answer': 'Cogstate ensures that our security and quality infrastructure scale effectively with business growth through strategic measures. This begins with rigorous risk assessment and management to identify potential vulnerabilities and threats. We adopt scalable technology and tools, leveraging cloud-based services that readily adjust to demands. Compliance with industry regulations and standards is a constant priority, and we continuously train and make our employees aware of security and quality protocols. Ongoing monitoring, auditing, and comprehensive incident response plans are in place, alongside data protection, privacy measures, and responsible vendor management. Scalability extends to the workforce, ensuring the right talent is on-boarded to manage any expanded infrastructure. We emphasize a culture of continuous improvement, where executive leadership and governance play a crucial role in setting priorities and ensuring accountability. In addition to these measures, we prioritize developing a Scalable Security Culture. This involves embedding security awareness at every level of the organization, ensuring every employee understands their role in maintaining security and quality standards. This cultural shift is vital for fostering an environment where security is a continuous, evolving process, adapting to new challenges as the company grows. Furthermore, our approach to scaling includes robust Disaster Recovery and Business Continuity plans. These plans ensure minimal operational disruption and quick recovery in the face of incidents ranging from cyber-attacks to natural disasters. This planning is integral to our commitment to maintain seamless service and protect our client’s data, regardless of unforeseen challenges. Through these comprehensive strategies, Cogstate is dedicated to maintaining a high level of security and quality, ensuri ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 11:33:03,489 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': 'hiS&E Vendor Communication Plan', 'description': "This document provides detailed information about Cogstate, Inc., including their communication plan, evidence breakdown, and regulatory compliance. It discusses Cogstate's experience in clinical trials, partnerships, and their recognition in the industry. The document also outlines Cogstate's compliance with various regulatory standards such as HIPAA, GDPR, and 21 CFR Part 11.", 'qa_pairs': [{'question': 'Please provide documentation for: Performance specifications for the integrated hardware, Output data specifications, Overview of software system tests, Limitations to the verification testing – e.g. specific known items that were not tested during verifications', 'answer': 'With Cogstate digital cognitive testing solutions or rater training solutions, Cogstate can adapt to different types of hardware, so long as they meet requirements on our minimum requirements list. Cogstate can also adapt our data outputs to meet the needs of the study and the study team.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Validation Studies', 'answer': 'Please visit this link.', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Please describe the company’s documented methodology for the development and validation of the DHT, including a documented risk assessment.', 'answer': 'All digital cognitive tests are created and tested in accordance with our SOPs. We are happy to provide a SOP list upon request.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Please describe the development or evaluations performed that ensure the DHT was designed, developed, and deployed in an effective and equitable manner.', 'answer': 'All digital cognitive tests are created and tested in accordance with our SOPs. We are happy to provide a SOP list upon request.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Publication List', 'answer': 'Cogstate has been involved with or acknowledged in over 600 publications. Please find visit this link for a comprehensive list of our publications.', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Experience providing services in clinical trials in the pharmaceutical industry', 'answer': 'Cogstate has supported more than 460 clinical trials in all phases and across 60+ indications. Cogstate has the most expertise in Alzheimer’s Disease, having supported 100+ clinical trials across 3,200 sites worldwide. More details around our therapeutic experience in different indications can be found at this link.', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Experience providing services in clinical trials with academic institutions', 'answer': 'Cogstate has been selected to support research and academic collaborations in more than 1,800 studies across 190 indications, resulting in hundreds of peer reviewed publications.', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Studies sponsored by the company', 'answer': 'N/A', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Human Factor Studies', 'answer': 'None', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Awards', 'answer': 'In 2020 Cogstate was awarded a Digital Biomarker Award from Alzheimer’s Drug Discovery Foundation (ADDF).', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Partnerships in the Industry', 'answer': 'Cogstate has partnerships with several eCOA companies, including Clario and Clinical Ink. However we can work with AbbVie to find the suitable eCOA vendor for a study, if needed.', 'domain': 'General', 'type': 'open-ended'}, {'question': 'HIPAA Compliance', 'answer': 'Yes. While Cogstate is not a covered entity, Cogstate has established several policies for ensuring data security compliance with HIPAA.', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'GDPR Compliance', 'answer': 'Yes. While Cogstate is not a covered entity, Cogstate has established several policies for ensuring data s ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 11:33:03,532 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': '', 'description': '', 'qa_pairs': [{'question': 'HIPAA Compliance', 'answer': 'Yes. While Cogstate is not a covered entity, Cogstate has established several policies for ensuring data security compliance with HIPAA.', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'GDPR Compliance', 'answer': 'Yes. While Cogstate is not a covered entity, Cogstate has established several policies for ensuring data security compliance with GDPR.', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': '21 CFR Part 11 Compliance', 'answer': 'Yes. While Cogstate is not a covered entity, Cogstate has established several policies for ensuring data security compliance with 21 CFR Part 11.', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'GCP Compliant', 'answer': 'Yes. While Cogstate is not a covered entity, Cogstate has established several policies for ensuring data security compliance with GCP.', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'ISO 13485', 'answer': 'No', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Regulatory Pathway, Interactions, and Clearances', 'answer': "In all submissions to regulatory authorities in the past three years, Cogstate has served as a contributor. Cogstate doesn't interact directly with regulatory agencies. Instead, we provide content and input to our customers, who then interact with agencies. The interaction Cogstate has had with an agency was in 2022 with the FDA, but that wasn't a submission, it was an inspection, which resulted in no 483s.", 'domain': 'Compliance', 'type': 'open-ended'}, {'question': 'Regulatory Interactions with Algorithm', 'answer': 'N/A', 'domain': 'Compliance', 'type': 'open-ended'}, {'question': 'Regulatory approvals (Specify approvals in which countries, Any pending approvals and regulatory feedback?)', 'answer': "In all submissions to regulatory authorities in the past three years, Cogstate has served as a contributor. Cogstate doesn't interact directly with regulatory agencies. Instead, we provide content and input to our customers, who then interact with agencies. The interaction Cogstate has had with an agency was in 2022 with the FDA, but that wasn't a submission, it was an inspection, which resulted in no 483s.", 'domain': 'Compliance', 'type': 'open-ended'}, {'question': 'Define how the company assesses global regulatory requirements and stays current on regulatory rulings', 'answer': 'Cogstate’s in-house quality assurance (QA) reviews and ensures compliance on all regulatory rulings.', 'domain': 'Compliance', 'type': 'open-ended'}, {'question': 'Will data be stored in the digital health technology? How long will the data be stored? Is data automatically encrypted? How will the data be transferred?', 'answer': 'All data are stored on Microsoft Azure, and RedCap Cloud’s data server. Cogstate maintains controlled access areas for systems that contain data. Access to data is limited by user access levels/privileges. As the data collected by Cogstate is in the cloud, the data collected on the device is automatically made available in the database. Data is transmitted via SSL from the web client to our platform. Please also note that Cogstate has a suite of policies to govern how data/client PII is handled. All data is encrypted in-transit and at rest. Cogstate utilizes AES 256 bit encryption for data at rest (both active and backup), and the latest TLS encryption for data in transit. Dependent upon the services provided by Cogstate in a study, the Cogstate Data Manager will discuss and agree with Sponsor on the format of data to be transferred, the schedule of transfers, the quality checks to be performed, and the process for query resolution. These details will be reflected in a data management plan.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Is the data uploaded in “real-time” into the software? Data should be retrieved from the technology/sensor as soon as possible', 'answer': 'If con ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 11:33:05,866 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': '', 'description': '', 'qa_pairs': [{'question': 'How is client PII handled?', 'answer': 'All data is encrypted in-transit and at rest. Cogstate utilizes AES 256 bit encryption for data at rest (both active and backup), and the latest TLS encryption for data in transit. Dependent upon the services provided by Cogstate in a study, the Cogstate Data Manager will discuss and agree with Sponsor on the format of data to be transferred, the schedule of transfers, the quality checks to be performed, and the process for query resolution. These details will be reflected in a data management plan.', 'domain': 'Security', 'type': 'open-ended'}, {'question': 'Is the data uploaded in “real-time” into the software?', 'answer': 'If connected to internet, the data is uploaded to the server throughout the assessment and routed back into the database CRFs after the processed outcomes are computed (which happen within a few minutes of the battery administration). If the device loses internet access partway through the assessment, the data will stop being uploaded throughout the assessment and instead be stored locally (encrypted) and will be uploaded to the Cogstate servers the next time the Cogstate battery is launched.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'If data will be stored on a cloud, what is the length of time the data will be stored on the cloud?', 'answer': 'Cogstate uses Microsoft Azure for all data storage. Our standard archiving procedure is 15 years.', 'domain': 'Compliance', 'type': 'open-ended'}, {'question': 'Describe the company’s controls for data transfers, and the controls to protect data integrity during such transfers.', 'answer': 'All data is encrypted in-transit and at rest. Cogstate utilizes AES 256 bit encryption for data at rest (both active and backup), and the latest TLS encryption for data in transit.', 'domain': 'Security', 'type': 'open-ended'}, {'question': 'Will any group (e.g. patients, sites, sponsors) be able to access any data in real time?', 'answer': 'Sites and sponsors will be able to access the data once uploaded into the CRFs. Patients will not be able to access any data in real time.', 'domain': 'Access Control', 'type': 'close-ended'}, {'question': 'What type of data is collected?', 'answer': 'This is dependent upon the type of service that Cogstate is providing. The Cogstate computerized cognitive testing battery collects only decimals and integers from the assessments, which can be used to measure and detect subtle drug-related changes. In terms of PII, we collect subject ID, sex, year of birth, and language preference.', 'domain': 'Data Collection', 'type': 'open-ended'}, {'question': 'Describe how any personally identifiable information is masked, such as video or audio recordings.', 'answer': 'This is dependent upon the type of service that Cogstate is providing. For the digital battery, we collect subject ID, sex, year of birth, and language preference. However, for central monitoring services, PII may be disclosed based on the nature of the service. Cogstate would be happy to discuss what service may suit AbbVie’s needs.', 'domain': 'Privacy', 'type': 'open-ended'}, {'question': 'Intended use of data', 'answer': 'This is dependent upon the type of service that Cogstate is providing.', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Where will the data be transferred to?', 'answer': 'This is dependent upon the type of service that Cogstate is providing.', 'domain': 'Data Transfer', 'type': 'open-ended'}, {'question': 'Describe how the data will flow to AbbVie', 'answer': 'This depends on the type of service that Cogstate provides. Cogstate would be happy to share more detailed data flows upon request.', 'domain': 'Data Flow', 'type': 'open-ended'}, {'question': 'What type of data will AbbVie receive? (raw vs. processed)', 'answer': 'Either academic data or process data can be received by AbbVie from Cogstate. This is dependent upon the type of ser ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 11:33:06,872 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': '', 'description': '', 'qa_pairs': [{'question': 'Does the DHT require any third-party data sources or integrations?', 'answer': 'This would be dependent upon the type of services Cogstate is providing and that AbbVie is needing for its study.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Will data be encrypted at risk or at rest?', 'answer': 'Cogstate utilizes AES 256 bit encryption for data at rest (both active and backup), and the latest TLS encryption for data in transit.', 'domain': 'Security', 'type': 'open-ended'}, {'question': 'How is missing data handled?', 'answer': 'Cogstate’s data management team will issue a query about the missing data, or other data discrepancies.', 'domain': 'Data Management', 'type': 'open-ended'}, {'question': 'Example of standard reports provided to sponsors', 'answer': 'Data reports can be dependent upon the sponsor and their needs. Examples include: monthly “unclean” interim data transfers of computerized digital data. For the “unclean” interim transfers, the data will likely contain unresolved queries. Data files are always cumulative, containing all data, including resolved queries and unresolved queries.', 'domain': 'Reporting', 'type': 'open-ended'}, {'question': 'Is more granular level data available upon sponsor request?', 'answer': 'Yes', 'domain': 'Data Management', 'type': 'close-ended'}, {'question': 'Hardware/Software', 'answer': 'Cogstate can work with multiple types of hardware. Cogstate would be pleased to discuss with AbbVie what might be best suitable for a proposed study. This may be a Lenovo tablet, an iPAD, or other tablet that is best suited for the study.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Make and Model', 'answer': 'This is dependent upon the needs of the study.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Battery Life', 'answer': 'Cogstate can work with multiple types of hardware. Cogstate would be pleased to discuss with AbbVie what might be best suitable for a proposed study.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Internet connectivity required to capture data', 'answer': 'Yes', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'API Availability', 'answer': 'No', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'SDK Availability', 'answer': 'No', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'Is integration with other systems/devices required?', 'answer': 'This depends on the type of service that Cogstate provides.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Can the technology be integrated with other systems/devices?', 'answer': 'Yes, Cogstate can work with multiple types of hardware. Cogstate would be pleased to discuss with AbbVie what might be best suitable for a proposed study.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Compatible operating system', 'answer': 'Cogstate is compatible with both iOS, Android, and Windows devices. The preferred system is dependent upon the type of study and timelines.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'BYOD vs. Provisioned Devices', 'answer': 'Cogstate is compatible with either BYOD or provisioned devices. The preferred system is dependent upon the type of study and timelines.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Describe the company’s provisioning processes including how replacement items will be handled', 'answer': 'If Cogstate is provisioning devices, back-ups are usually held either at a site or in the country for easy deployment.', 'domain': 'Logistics', 'type': 'open-ended'}, {'question': 'Please describe the company’s enterprise mobility management (EMM) procedure, such as will users be able to communicate on provisioned hardware, e.g. making a call?', 'answer': 'N/a – Users will not be able to communicate with provisioned hardware.', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'Da ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 11:33:08,092 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': '', 'description': '', 'qa_pairs': [{'question': 'Can dashboards be made available and updated in real-time?', 'answer': 'Yes, dashboards can be made available. The specifics of the dashboard will be determined by the needs of the study.', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'How will subject information appear in the software (i.e., coded by subject number)?', 'answer': 'For digital cognitive tests, it will be coded by subject number and visit number.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'How is the software accessed (i.e., web-based, downloaded onto equipment etc.)?', 'answer': 'This depends on the type of services provided by Cogstate.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'What is the hardware storage capacity?', 'answer': 'The type of hardware is dependent upon the services provided, the type of hardware, and timelines available.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'What versions of hardware or software are available (e.g., consumer vs. research)?', 'answer': 'This depends on the type of services provided by Cogstate.', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Are there any risks associated with versioning (modification to hardware/software)?', 'answer': 'No', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'Is a log maintained of who accesses the data server and when?', 'answer': 'Yes', 'domain': 'Security', 'type': 'close-ended'}, {'question': 'Access to data and/or software for sites, sponsor, and patient? If sponsor has access, will the sponsor have access to personally identifiable information?', 'answer': 'Clinical research associates (CRAs) may be given access to the data. PII will not be available.', 'domain': 'Security', 'type': 'open-ended'}, {'question': 'Does the company have a Coordinated Vulnerability Disclosure (CVD) policy? Does the company publish its security support lifetime and issue secure, prompt, and agile software updates once security issues are discovered? Does the organization track and share a Software Bill of Materials (SBOM)?', 'answer': 'No', 'domain': 'Security', 'type': 'close-ended'}, {'question': 'Are there technology-related AEs or Product Complaints?', 'answer': 'No', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'Is there an AE/Product Complaint reporting process in place?', 'answer': 'Yes - Standard Quarterly AE Reporting (based on information received from sites)', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'Does the company have the ability to monitor additional data?', 'answer': 'Yes, Cogstate can perform additional data management monitoring services', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'Could additional data require safety monitoring?', 'answer': 'If needed, yes, Cogstate can perform safety monitoring', 'domain': 'Safety', 'type': 'close-ended'}, {'question': 'Please describe how the company implements security controls for access (e.g., two-factor authentication, role-based access).', 'answer': 'Cogstate enforces both two-factor authentication and role-based access.', 'domain': 'Security', 'type': 'open-ended'}, {'question': 'Please describe the DHTs ability to generate audit trails, including the ability to document when a record/data is created, updated, overwritten, or deleted.', 'answer': 'Cogstate can generate audit trails.', 'domain': 'Quality', 'type': 'open-ended'}, {'question': 'Has the company been audited or inspected during the last two years? If yes, were there any major/critical observations?', 'answer': 'Yes, Cogstate participates in audits on a frequent basis. In the last two years, no major/critical observations were noted. Cogstate was also inspected by the FDA in 2022, which resulted in no 483s.', 'domain': 'Quality', 'type': 'open-ended'}, {'question': 'Is there a QMS in place?', 'answer': 'Yes, Cogstate uses Qualio QMS.', 'domain': 'Quality', 'type': 'close-ended ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 11:33:09,741 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': 'ensuring every employee understands their role in maintaining security and quality standards. This cultural shift is vital for fostering an environment where security is a continuous, evolving process, adapting to new challenges as the company grows. Furthermore, our approach to scaling includes robust Disaster Recovery and Business Continuity plans. These plans ensure minimal operational disruption and quick recovery in the face of incidents ranging from cyber-attacks to natural disasters. This planning is integral to our commitment to maintain seamless service and protect our client’s data, regardless of unforeseen challenges. Through these comprehensive strategies, Cogstate is dedicated to maintaining a high level of security and quality, ensuring resilience and adaptability as our business expands.', 'description': '', 'qa_pairs': [{'question': 'Provide financial information (i.e past three years of audited financial statements including their income statement and balance sheet)', 'answer': 'For our financial reports, please check [here](https://www.cogstate.com/investors/financial-reports/).', 'domain': 'Financial', 'type': 'open-ended'}, {'question': 'Annual revenue (Previous Year)', 'answer': '2023: $40,451,123', 'domain': 'Financial', 'type': 'open-ended'}, {'question': 'Amount Raised', 'answer': 'n/a', 'domain': 'Financial', 'type': 'open-ended'}, {'question': 'Last Raised', 'answer': 'n/a', 'domain': 'Financial', 'type': 'open-ended'}, {'question': 'Founded Year', 'answer': '1999', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Stage', 'answer': 'Public', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Investors', 'answer': 'Please see financial report.', 'domain': 'Financial', 'type': 'open-ended'}, {'question': 'Intellectual Property', 'answer': 'Cogstate owns the IP of our cognitive tests.', 'domain': 'Intellectual Property', 'type': 'open-ended'}, {'question': 'Cost', 'answer': 'Costing will be dependant upon the nature of a study. Cost factors include the services requested, the scale of the study', 'domain': 'Cost', 'type': 'open-ended'}, {'question': 'Shipping fees', 'answer': 'Please see above.', 'domain': 'Cost', 'type': 'open-ended'}, {'question': 'Minimum order requirements', 'answer': 'None', 'domain': 'Cost', 'type': 'open-ended'}, {'question': 'Provisioning and/or implementation timelines', 'answer': 'This is dependent upon services provided.', 'domain': 'Implementation', 'type': 'open-ended'}, {'question': 'Geographical regions where the technology can be implemented', 'answer': 'Worldwide', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Free sample available', 'answer': 'No', 'domain': 'General', 'type': 'close-ended'}, {'question': 'What is the PE firm’s strategy overall and with their business in particular?', 'answer': 'n/a', 'domain': 'Financial', 'type': 'open-ended'}, {'question': 'How much influence does the PE firm have over the direction of the company? How is the relationship and investment structured?', 'answer': 'n/a', 'domain': 'Financial', 'type': 'open-ended'}, {'question': 'Privacy Policy', 'answer': 'Please find our privacy policy here.', 'domain': 'Privacy', 'type': 'open-ended'}, {'question': 'Intended Population', 'answer': 'This is dependent upon the services requested.', 'domain': 'Usability', 'type': 'open-ended'}, {'question': 'Ease of Use', 'answer': 'Cogstate aims to ensure that the technology is easy to use for all populations, whether a study participant or coordinator.', 'domain': 'Usability', 'type': 'open-ended'}, {'question': 'Patient burden', 'answer': 'Minimal', 'domain': 'Usability', 'type': 'open-ended'}, {'question': 'User experience', 'answer': 'Cogstate services have received positive feedback from clients.', 'domain': 'Usability', 'type': 'open-ended'}, {'question': 'Will the DHT penetrate or potentially penetrate a user’s skin?', 'answer': 'No', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'Prescri ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 11:33:10,206 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': '', 'description': '', 'qa_pairs': [{'question': 'What differentiates you from your competitors?', 'answer': 'We are continually innovating, with a focus on ensuring we have superior digital cognitive testing available across a range of modalities that can be used in a range of settings. Our science team is actively engaged with the industry, regularly evaluating market developments and trends. We regularly scan the market for new entrants or developments within existing competitors. We have close relationships with major customers, ensuring that we understand their current and future needs and adapt our offering to meet those needs (for example, delivery of fully remote clinical trials).', 'domain': 'General', 'type': 'open-ended'}, {'question': 'What are the main challenges that you face in your industry?', 'answer': 'Cogstate provides proprietary digital brain health assessments along with scientific and operational expertise in respect of the assessment of cognition in the context of clinical trials. A risk to Cogstate is that it must continually evolve its offering, with new technology, new delivery modalities, better data analytics and new systems to ensure that it remains a leader in a competitive market. Additionally, it is expected that the launch of new Alzheimer’s disease treatments will bring an increase in demand for brain health assessment, leading to an increase in competition in the space.', 'domain': 'General', 'type': 'open-ended'}, {'question': 'What are the biggest opportunities?', 'answer': 'Cogstate provides proprietary digital brain health assessments along with scientific and operational expertise in respect of the assessment of cognition in the context of clinical trials. A risk to Cogstate is that it must continually evolve its offering, with new technology, new delivery modalities, better data analytics and new systems to ensure that it remains a leader in a competitive market. Additionally, it is expected that the launch of new Alzheimer’s disease treatments will bring an increase in demand for brain health assessment, leading to an increase in competition in the space.', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Services available for consumer use', 'answer': 'Yes', 'domain': 'General', 'type': 'close-ended'}, {'question': 'Private or publicly owned company', 'answer': 'Public', 'domain': 'General', 'type': 'close-ended'}, {'question': 'Parent Organization', 'answer': 'Cogstate, Ltd.', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Subsidiary', 'answer': 'n/a', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Total number of employees (Capacity) and Size of following teams: Engineering, Clinical, Regulatory', 'answer': 'Engineering: 18, Clinical: 76, Regulatory: 3', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Certified small business, and/or woman, minority, veteran, LGBT owned enterprise', 'answer': 'No', 'domain': 'General', 'type': 'close-ended'}, {'question': 'Headquarters', 'answer': 'Australia: 38, United States: 121, United Kingdom: 11', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Therapeutic Area', 'answer': 'Central Nervous System, Rare Diseases', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Indication(s)', 'answer': 'Alzheimer’s Disease and Dementia, Parkinson’s Disease, Major Depressive Disorder, Multiple Sclerosis, Schizophrenia, Oncology, and more.', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Measures', 'answer': 'This is dependent upon protocols. The Cogstate Digital Cognitive Assessments have been used as measures for primary endpoints, secondary endpoints, as well as safety endpoints in a trial.', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Key product offerings and services', 'answer': 'Cogstate Computerized Digital Testing, Endpoint Data Quality, Rater Training, Central Monitoring, Central Rating', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Additiona ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 11:33:10,207 - rfiprocessor.core.agents.rfi_parser - INFO - Successfully parsed document. Found 135 Q&A pairs.
# 2025-07-22 11:33:10,208 - __main__ - INFO - Saved parsed output to json_output/Cogstate_RFI_AbbVie S&E Vendor Communication Plan.json
# 2025-07-22 11:33:10,209 - __main__ - INFO - Successfully validated JSON structure for doc ID 3.
# ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 11:34:12,162 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': '', 'description': "Cogstate solutions have been used in over 90 Alzheimer’s disease clinical trials, guiding decision-making for cognitive safety and efficacy across many indications and all phases of development. Our range of Alzheimer’s disease clinical trials experience includes all phases of development for Pre-clinical Alzheimer's disease (AD), Prodromal AD/Mild cognitive impairment (MCI), and Early AD. Cogstate has developed computerized cognitive tests to dramatically increase the sensitivity and specificity of the measurement of human cognitive processes. Cogstate’s tests are rapid and reliable, and most importantly, have demonstrated sensitivity to subtle drug related changes in cognition. They have been designed, developed and validated to withstand the numerous operational challenges of conducting clinical trials, such as testing patient groups with unique characteristics, working with sites in countries or cultures with limited experience with cognitive testing and protocol schedules where there is often limited time available for assessment. Cogstate tests have consistently demonstrated sensitivity to both the facilitatory effects of cognitive enhancers and to the negative effects of sedative drugs in healthy humans, as well as sensitivity to the effects of drugs used to treat dementia in Alzheimer’s disease and cognitive impairment in schizophrenia, depression and ADHD. The scientific rationale and support for the validity, reliability and sensitivity to drug effects in clinical trials has been detailed in hundreds of publications.", 'qa_pairs': [{'question': "Q14. If the CRO has multiple disease specialties and core capabilities, how often are they contracted and performed by scientific staff? (What experience does the CRO have with central nervous system diseases and Alzheimer's drug discovery specifically?)", 'answer': "Cogstate solutions have been used in over 90 Alzheimer’s disease clinical trials, guiding decision-making for cognitive safety and efficacy across many indications and all phases of development. Our range of Alzheimer’s disease clinical trials experience includes all phases of development for Pre-clinical Alzheimer's disease (AD), Prodromal AD/Mild cognitive impairment (MCI), and Early AD.", 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Q15. Can the CRO provide a summary of facilities, equipment and staff, e.g. in form of a PDF brochure or presentation?', 'answer': 'Yes', 'domain': 'General', 'type': 'close-ended'}, {'question': 'Q16. Does the CRO offer flexibility in experimental design and project execution?', 'answer': 'Yes', 'domain': 'General', 'type': 'close-ended'}, {'question': 'Q17. If applicable, does the CRO provide clearly defined controls, and validation data for assays and/or animal models to be used? Is any of this published?', 'answer': 'Cogstate has developed computerized cognitive tests to dramatically increase the sensitivity and specificity of the measurement of human cognitive processes. Cogstate’s tests are rapid and reliable, and most importantly, have demonstrated sensitivity to subtle drug related changes in cognition. They have been designed, developed and validated to withstand the numerous operational challenges of conducting clinical trials, such as testing patient groups with unique characteristics, working with sites in countries or cultures with limited experience with cognitive testing and protocol schedules where there is often limited time available for assessment. Cogstate tests have consistently demonstrated sensitivity to both the facilitatory effects of cognitive enhancers and to the negative effects of sedative drugs in healthy humans, as well as sensitivity to the effects of drugs used to treat dementia in Alzheimer’s disease and cognitive impairment in schizophrenia, depression and ADHD. The scientific rationale and support for the validity, reliability and sensitivity to drug effects in clinical trials has been detailed in h ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 11:34:32,271 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': 'To optimize the use of CROs by academia and early-stage companies, the ADDF has partnered with Science Exchange to launch the ADDF ACCESS program. ADDF ACCESS provides an online marketplace of vetted service providers and educational resources. In our efforts to understand your company’s capabilities and to accurately highlight these to our scientific community, we would appreciate your time in answering the following questions.', 'description': 'Cogstate, Ltd. is located at 195 Church St, Level 4, New Haven, 06510, CT, USA. The company is publicly traded on the Australian stock exchange (ASX) under ticker CGS. Cogstate has been in operation for over 18 years, was founded in 1999, and went public on the Australian Securities Exchange in 2004. All growth has been organic, with no mergers, acquisitions, or name changes. Cogstate Clinical Trials Revenue totaled A$34.7 million for the financial year to 30 June 2017. The company has 5 primary offices located in Melbourne, Australia (corporate headquarters), New Haven, CT, USA (operational headquarters), New York, NY, USA, Boston, MA, USA, and London, UK.', 'qa_pairs': [{'question': 'How did you hear about ACCESS?', 'answer': 'Cogstate learned about ACCESS through the Science Exchange website.', 'domain': 'General', 'type': 'open-ended'}, {'question': 'What is the CRO clientele break down?', 'answer': 'Large Pharma or Biotech: 60%, Small to mid-size pharma or biotech 40%, Academic sponsors: Cogstate technology is utilized in hundreds of academic trials across many indications, and is to qualifying non-commercial trials at little or no cost to the researcher. This reflects the value that Cogstate places on contributing to and participating in ongoing academic studies and public-private partnerships. US 70% Europe 20% Other 10%', 'domain': 'Business', 'type': 'open-ended'}, {'question': 'What is the company structure? Public/private? Subsidiary of a parent or holding company?', 'answer': 'Cogstate is publicly traded on the Australian stock exchange (ASX) under ticker CGS. The Cogstate Group comprises Cogstate Ltd and six subsidiaries that are directly or indirectly all wholly owned: Cogstate Ltd, Cogstate Inc, Cogstate Health Inc, Cogstate Healthcare LLC, Cogstate Sports Pty Ltd, Cogstate Canada Inc, Cogstate Spain SL.', 'domain': 'Business', 'type': 'open-ended'}, {'question': 'What is the company size (by revenue, by staff) and number of sites? Which site is the head quarter?', 'answer': 'Cogstate Clinical Trials Revenue totaled A$34.7 million for the financial year to 30 June 2017. Cogstate headcount totals over 275 staff: >175 full-time employees, >100 consultant neuropsychologists who provide in-language local rater support in 30 countries. Cogstate has 5 primary offices in the following locations: Melbourne, Australia (corporate headquarters), New Haven, CT, USA (operational headquarters), New York, NY, USA, Boston, MA, USA, London, UK.', 'domain': 'Business', 'type': 'open-ended'}, {'question': 'How many years in operation? Were there any recent mergers, acquisitions or name changes (<5 years)?', 'answer': 'Cogstate has been in operation for over 18 years -- was founded in 1999 and went public on the Australian Securities Exchange in 2004 (ASX.CGS). All growth has been organic, and there have been no mergers, acquisitions or name changes.', 'domain': 'Business', 'type': 'open-ended'}, {'question': 'What % of technical staff have PhDs and what is the average length of industry experience?', 'answer': '100% of Cogstate’s scientific leadership holds PhDs; as well as all members of our 100-person global network of expert neuropsychologist consultants. Further, 40% of Cogstate’s entire global staff hold advanced degrees.', 'domain': 'Human Resources', 'type': 'open-ended'}], 'meta_data': {'company_name': 'Cogstate, Ltd.', 'date': 'N/A', 'category': 'RFI', 'type': 'PastResponse'}}
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 11:34:32,273 - rfiprocessor.core.agents.rfi_parser - INFO - Successfully parsed document. Found 47 Q&A pairs.
# 2025-07-22 11:34:32,274 - __main__ - INFO - Saved parsed output to json_output/ADDF ACCESS Request for Information.json
# 2025-07-22 11:34:32,274 - __main__ - INFO - Successfully validated JSON structure for doc ID 10.
# 2025-07-22 11:34:32,275 - rfiprocessor.services.db_handler - INFO - Updating document ID 10 with: {'rfi_json_payload': {'summary': '## Solution Overview\nOur proposed solution leverages cutting-edge technology to address the specific needs within the life sciences and healthcare sectors. By integrating advanced data analytics with user-friendly interfaces, we ensure streamlined operations and enhanced decision-making capabilities. Our platform is designed to adapt to the evolving demands of the industry, providing a robust foundation for future growth and innovation.\n\n## Technical Capabilities\nThe technical architecture of our solution is built on a scalable and secure cloud-based infrastructure. This ensures high availability and reliability, essential for mission-critical applications. Our system supports seamless integration with existing enterprise systems, facilitating efficient data exchange and interoperability. Advanced security protocols are embedded to protect sensitive information and maintain compliance with industry standards.\n\n## Regulatory Compliance\nWe are committed to maintaining the highest standards of regulatory compliance across all operations. Our solution is fully compliant with HIPAA, GDPR, and other relevant regulations, ensuring the protection of patient data and privacy. Regular audits and updates are conducted to align with the latest regulatory requirements, providing peace of mind to our clients.\n\n## Implementation Timeline\nThe implementation of our solution follows a structured timeline to ensure timely delivery and minimal disruption to existing operations. Our experienced project management team collaborates closely with stakeholders to define clear milestones and deliverables. We aim to achieve full deployment within a six-month period, including comprehensive training and support for end-users.\n\n## Key Differentiators\nOur solution stands out due to its innovative use of artificial intelligence and machine learning to drive insights and efficiencies. We offer unparalleled customization options, allowing clients to tailor the platform to their unique needs. Additionally, our dedicated customer support team provides 24/7 assistance, ensuring any issues are resolved promptly and effectively.\n\n## Support and Maintenance\nPost-implementation, we offer comprehensive support and maintenance services to ensure the continued success of our solution. Our team is available around the clock to address any technical issues and provide updates as needed. Regular system enhancements and updates are included to keep the platform at the forefront of technological advancements.\n\nCompany Name: Cogstate', 'description': "Cogstate, Ltd. is located at 195 Church St, Level 4, New Haven, 06510, CT, USA. The company is publicly traded on the Australian stock exchange (ASX) under ticker CGS. Cogstate has been in operation for over 18 years, was founded in 1999, and went public on the Australian Securities Exchange in 2004. All growth has been organic, with no mergers, acquisitions, or name changes. Cogstate Clinical Trials Revenue totaled A$34.7 million for the financial year to 30 June 2017. The company has 5 primary offices located in Melbourne, Australia (corporate headquarters), New Haven, CT, USA (operational headquarters), New York, NY, USA, Boston, MA, USA, and London, UK.\n\nCogstate has 5 primary offices in the following locations:\n\n- Melbourne, Australia (corporate headquarters)\n- New Haven, CT, USA (operational headquarters)\n- New York, NY, USA\n- Boston, MA, USA\n- London, UK\n\nPaul remains an active researcher. He is appointed Professor at the Florey Institute for Neuroscience and Mental Health. He is currently clinical co-chair of the Australian Imaging Biomakers and Lifestyle (AIBL) study. Paul has published over 250 research articles in international peer-reviewed scientific journals, and has co-authored 10 book chapters.\n\nGeorge Hunnewell, Chief Operating Officer and President, C ...
# 2025-07-22 11:34:32,278 - __main__ - INFO - Successfully parsed and stored JSON for document ID 10.
# Parsing RFI/RFP documents: 100%|██████████| 6/6 [01:57<00:00, 19.60s/it]
# 2025-07-22 11:34:32,279 - __main__ - INFO - --- Ingestion Pipeline Finished ---
# 2025-07-22 11:34:32,279 - __main__ - INFO - Application finished.

# %%
from rfiprocessor.db.database import get_db_session
from rfiprocessor.services.db_handler import DatabaseHandler
from rfiprocessor.db.db_models import Document, IngestionStatus
from rfiprocessor.services.chunker import ChunkerService
from config.config import Config

# Setup config and chunker
config = Config()
chunk_size = getattr(config, "CHUNK_SIZE", 1000)
chunk_overlap = getattr(config, "CHUNK_OVERLAP", 150)
chunker = ChunkerService(chunk_size=chunk_size, chunk_overlap=chunk_overlap)

# Get a database session and handler
db_session_generator = get_db_session()
db_session = next(db_session_generator)
db_handler = DatabaseHandler(db_session)

# Fetch all documents
docs = db_session.query(Document).all()
if not docs:
    raise ValueError("No documents found in the database.")

for doc in docs:
    print("="*60)
    print(f"Document: {doc.source_filename} (type: {doc.document_type})")
    try:
        if doc.document_type == "RFI/RFP" and doc.rfi_json_payload:
            markdown_content = ""  # Not used for RFI/RFP
            print("Chunking as RFI/RFP (using JSON payload)...")
        elif doc.markdown_filepath:
            with open(doc.markdown_filepath, 'r', encoding='utf-8') as f:
                markdown_content = f.read()
            print("Chunking as supporting document (using markdown content)...")
        else:
            print("Skipping: Document is missing required data for chunking.")
            continue

        chunks_data = chunker.create_chunks_for_document(doc, markdown_content)
        print(f"Number of chunks: {len(chunks_data)}")

        if chunks_data:
            db_handler.add_chunks_to_document(doc.id, chunks_data)
            # Optionally, update the document status to CHUNKED
            db_handler.update_document(doc.id, {"ingestion_status": IngestionStatus.CHUNKED})
            print("Chunks saved to database.")
        else:
            print("No chunks created for this document.")

    except Exception as e:
        print(f"Error processing document: {e}")

print("="*60)
print("Done chunking and saving all documents.")
# Out:
# 2025-07-22 11:44:17,587 - rfiprocessor.services.chunker - INFO - ChunkerService initialized with chunk_size=2000 and chunk_overlap=200
# 2025-07-22 11:44:17,594 - rfiprocessor.services.chunker - INFO - Creating chunks for document ID 3 (Type: RFI/RFP)
# 2025-07-22 11:44:17,594 - rfiprocessor.services.chunker - INFO - Created 135 Q&A-based chunks for document ID 3.
# 2025-07-22 11:44:17,604 - rfiprocessor.services.db_handler - INFO - Added 135 chunks to document ID 3.
# 2025-07-22 11:44:17,622 - rfiprocessor.services.db_handler - INFO - Updating document ID 3 with: {'ingestion_status': <IngestionStatus.CHUNKED: 'CHUNKED'>}
# 2025-07-22 11:44:17,624 - rfiprocessor.services.chunker - INFO - Creating chunks for document ID 5 (Type: Supporting Document)
# 2025-07-22 11:44:17,624 - rfiprocessor.services.chunker - WARNING - Markdown content for document ID 5 is empty. Skipping chunking.
# 2025-07-22 11:44:17,625 - rfiprocessor.services.chunker - INFO - Creating chunks for document ID 6 (Type: Supporting Document)
# 2025-07-22 11:44:17,625 - rfiprocessor.services.chunker - INFO - Created 2 semantic chunks for document ID 6.
# 2025-07-22 11:44:17,626 - rfiprocessor.services.db_handler - INFO - Added 2 chunks to document ID 6.
# 2025-07-22 11:44:17,627 - rfiprocessor.services.db_handler - INFO - Updating document ID 6 with: {'ingestion_status': <IngestionStatus.CHUNKED: 'CHUNKED'>}
# 2025-07-22 11:44:17,629 - rfiprocessor.services.chunker - INFO - Creating chunks for document ID 7 (Type: Supporting Document)
# 2025-07-22 11:44:17,629 - rfiprocessor.services.chunker - WARNING - Markdown content for document ID 7 is empty. Skipping chunking.
# 2025-07-22 11:44:17,630 - rfiprocessor.services.chunker - INFO - Creating chunks for document ID 9 (Type: RFI/RFP)
# 2025-07-22 11:44:17,630 - rfiprocessor.services.chunker - INFO - Created 87 Q&A-based chunks for document ID 9.
# 2025-07-22 11:44:17,633 - rfiprocessor.services.db_handler - INFO - Added 87 chunks to document ID 9.
# 2025-07-22 11:44:17,642 - rfiprocessor.services.db_handler - INFO - Updating document ID 9 with: {'ingestion_status': <IngestionStatus.CHUNKED: 'CHUNKED'>}
# 2025-07-22 11:44:17,644 - rfiprocessor.services.chunker - INFO - Creating chunks for document ID 10 (Type: RFI/RFP)
# 2025-07-22 11:44:17,644 - rfiprocessor.services.chunker - INFO - Created 47 Q&A-based chunks for document ID 10.
# 2025-07-22 11:44:17,647 - rfiprocessor.services.db_handler - INFO - Added 47 chunks to document ID 10.
# 2025-07-22 11:44:17,651 - rfiprocessor.services.db_handler - INFO - Updating document ID 10 with: {'ingestion_status': <IngestionStatus.CHUNKED: 'CHUNKED'>}
# ============================================================
# Document: .DS_Store (type: None)
# Skipping: Document is missing required data for chunking.
# ============================================================
# Document: Copy of AbbVie Remediation Assessment- IT Security Privacy- Cogstate v10 (Additional Info) 3 Feb 2016.xlsx (type: None)
# Skipping: Document is missing required data for chunking.
# ============================================================
# Document: Cogstate_RFI_AbbVie S&E Vendor Communication Plan.docx (type: RFI/RFP)
# Chunking as RFI/RFP (using JSON payload)...
# Number of chunks: 135
# Chunks saved to database.
# ============================================================
# Document: Attachment 2.xlsx (type: None)
# Skipping: Document is missing required data for chunking.
# ============================================================
# Document: Corporate Org Chart.pdf (type: Supporting Document)
# Chunking as supporting document (using markdown content)...
# Number of chunks: 0
# No chunks created for this document.
# ============================================================
# Document: Attachment 1 - ISO Certificate.pdf (type: Supporting Document)
# Chunking as supporting document (using markdown content)...
# Number of chunks: 2
# Chunks saved to database.
# ============================================================
# Document: Abbvie.pdf (type: Supporting Document)
# Chunking as supporting document (using markdown content)...
# Number of chunks: 0
# No chunks created for this document.
# ============================================================
# Document: AbbVie_Recruitment Survey_Cogstate 2016 -FINAL.doc (type: None)
# Skipping: Document is missing required data for chunking.
# ============================================================
# Document: Cogstate_Acadia_CHDR_Ph1 Challenge_HV_CT QualityQuestionnaire_SoftwareSupplier_28 Jan 2022_V1.0.pdf (type: RFI/RFP)
# Chunking as RFI/RFP (using JSON payload)...
# Number of chunks: 87
# Chunks saved to database.
# ============================================================
# Document: ADDF ACCESS Request for Information.docx (type: RFI/RFP)
# Chunking as RFI/RFP (using JSON payload)...
# Number of chunks: 47
# Chunks saved to database.
# ============================================================
# Done chunking and saving all documents.

# %%
import os
import shutil
from tqdm import tqdm

# --- Core Application Imports ---
from config.config import Config
from rfiprocessor.utils.logger import get_logger
from rfiprocessor.core.agents.rfi_parser import RfiParserAgent

# --- Database Imports ---
from rfiprocessor.db.database import init_db, get_db_session
from rfiprocessor.services.db_handler import DatabaseHandler
from rfiprocessor.db.db_models import IngestionStatus
from rfiprocessor.models.data_models import RFIJson

# --- Initial Setup ---
config = Config()
logger = get_logger(__name__)


def run_chunking_pipeline():
    """
    Scans for new files and processes them through the ingestion pipeline.
    """
    logger.info("--- Starting Ingestion Pipeline ---")

    # Initialize services and agents
    chunker = ChunkerService(config.CHUNK_SIZE, config. CHUNK_OVERLAP)

    db_session_generator = get_db_session()
    db_session = next(db_session_generator)
    try:
        db_handler = DatabaseHandler(db_session)
        # --- Step 4: Document Chunking ---
        logger.info("--- Starting Document Chunking Step ---")
        docs_to_chunk = db_handler.get_documents_by_status(IngestionStatus.PARSED)

        if not docs_to_chunk:
            logger.info("No new parsed documents to chunk.")
        else:
            logger.info(f"Found {len(docs_to_chunk)} documents to chunk.")

        for doc in tqdm(docs_to_chunk, desc="Chunking documents"):
            try:
                logger.info(f"Chunking document: {doc.source_filename} (ID: {doc.id})")
                
                # We need the markdown content for supporting docs.
                # RFI docs don't need it for chunking, but it's cleaner to always have it.
                with open(doc.markdown_filepath, 'r', encoding='utf-8') as f:
                    markdown_content = f.read()
                    
                # Call the chunker service
                chunks_data = chunker.create_chunks_for_document(doc, markdown_content)
                
                if not chunks_data:
                    logger.warning(f"No chunks were created for document ID {doc.id}. Moving to next stage.")
                else:
                    # Add the created chunks to the database
                    db_handler.add_chunks_to_document(doc.id, chunks_data)
                
                # Update the document status to CHUNKED
                db_handler.update_document(doc.id, {"ingestion_status": IngestionStatus.CHUNKED})
                logger.info(f"Successfully chunked and stored chunks for document ID {doc.id}.")

            except Exception as e:
                error_msg = f"Error chunking document ID {doc.id}: {e}"
                logger.error(error_msg, exc_info=True)
                db_handler.update_document(
                    doc.id,
                    {"ingestion_status": IngestionStatus.FAILED, "error_message": error_msg}
                )

    finally:
        db_session.close()
        logger.info("--- Ingestion Pipeline Finished ---")

# The if __name__ == "__main__": block remains the same
if __name__ == "__main__":
    logger.info("Application started.")
    init_db()
    run_ingestion_pipeline()
    logger.info("Application finished.")
# Out:
# 2025-07-22 11:34:32,298 - __main__ - INFO - Application started.
# 2025-07-22 11:34:32,299 - rfiprocessor.db.database - INFO - Initializing database and creating tables if they don't exist...
# 2025-07-22 11:34:32,304 - rfiprocessor.db.database - INFO - Database initialization complete.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 81
#      79 logger.info("Application started.")
#      80 init_db()
# ---> 81 run_ingestion_pipeline()
#      82 logger.info("Application finished.")
#
# NameError: name 'run_ingestion_pipeline' is not defined
