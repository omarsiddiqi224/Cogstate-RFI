# %%
import os
import shutil
from tqdm import tqdm

# --- Core Application Imports ---
from config.config import Config
from rfiprocessor.utils.logger import get_logger
from rfiprocessor.utils.wlak_dir import list_all_file_paths
from rfiprocessor.services.markdown_converter import MarkdownConverter, ProcessorType
from rfiprocessor.core.agents.document_classifier import DocumentClassifierAgent

# --- Database Imports ---
from rfiprocessor.db.database import init_db, get_db_session
from rfiprocessor.services.db_handler import DatabaseHandler
from rfiprocessor.db.db_models import IngestionStatus

# --- Initial Setup ---
config = Config()
logger = get_logger(__name__)

def run_markdown_conversion_pipeline():
    """
    Scans for new files, converts them to markdown, and tracks progress in the database.
    """

    # --- Step 1: Markdown Conversion ---
    logger.info("--- Starting Markdown Conversion Pipeline ---")
    
    # Initialize services
    converter = MarkdownConverter()
    classifier = DocumentClassifierAgent()
    
    # Get a database session and initialize the handler
    db_session_generator = get_db_session()
    db_session = next(db_session_generator)
    try:
        db_handler = DatabaseHandler(db_session)

        # 1. Scan the incoming directory for all files
        all_files = list_all_file_paths(config.INCOMING_DATA_PATH)
        
        # 2. Register all found files in the database if they don't exist
        logger.info(f"Found {len(all_files)} files. Registering new files in the database...")
        for file_path in all_files:
            # This will add the document if new, or get the existing one.
            db_handler.add_or_get_document(source_filepath=file_path)
        
        # 3. Fetch only the documents that are pending conversion
        pending_docs = db_handler.get_documents_by_status(IngestionStatus.PENDING)
        
        # Filter out unsupported files
        valid_docs = [
            doc for doc in pending_docs 
            if any(doc.source_filename.lower().endswith(ext) for ext in config.VALID_FILE_EXTNS)
        ]
        
        if not valid_docs:
            logger.info("No new documents to convert. Pipeline finished.")
            return

        logger.info(f"Found {len(valid_docs)} new documents to process.")

        # 4. Process each pending document
        for doc in tqdm(valid_docs, desc="Converting files to Markdown"):
            try:
                logger.info(f"Processing document: {doc.source_filename} (ID: {doc.id})")
                
                # Determine which processor to use
                processor_to_use = ProcessorType.MARKITDOWN
                if any(doc.source_filename.lower().endswith(ext) for ext in config.UNSTRD_FILE_EXTNS):
                    processor_to_use = ProcessorType.UNSTRUCTURED

                # Convert the file to markdown
                markdown_content, markdown_path = converter.convert_to_markdown(
                    file_path=doc.source_filepath,
                    processor=processor_to_use
                )
                
                # Move the original raw file to the processed directory
                destination_path = os.path.join(config.PROCESSED_DATA_PATH, doc.source_filename)
                os.makedirs(os.path.dirname(destination_path), exist_ok=True)
                shutil.move(doc.source_filepath, destination_path)
                
                # Update the document record in the database with the new status and paths
                updates = {
                    "markdown_filepath": markdown_path,
                    "processed_filepath": destination_path,
                    "ingestion_status": IngestionStatus.MARKDOWN_CONVERTED,
                    "error_message": None # Clear any previous errors
                }
                db_handler.update_document(doc.id, updates)
                logger.info(f"Successfully converted and moved document ID {doc.id}.")

            except Exception as e:
                logger.error(f"Error processing document ID {doc.id} ('{doc.source_filename}'): {e}", exc_info=True)
                # Update the document record to reflect the failure
                db_handler.update_document(
                    doc.id,
                    {
                        "ingestion_status": IngestionStatus.FAILED,
                        "error_message": str(e)
                    }
                )

    finally:
        # Ensure the database session is closed
        db_session.close()
        logger.info("--- Markdown Conversion Pipeline Finished ---")

    # Get a database session and initialize the handler
    db_session_generator = get_db_session()
    db_session = next(db_session_generator)
    try:
        db_handler = DatabaseHandler(db_session)

        # --- Step 2: Document Classification ---
        logger.info("--- Starting Document Classification Step ---")
        docs_to_classify = db_handler.get_documents_by_status(IngestionStatus.MARKDOWN_CONVERTED)
        
        if not docs_to_classify:
            logger.info("No new documents to classify.")
        else:
            logger.info(f"Found {len(docs_to_classify)} documents to classify.")

        for doc in tqdm(docs_to_classify, desc="Classifying documents"):
            try:
                logger.info(f"Classifying document: {doc.source_filename} (ID: {doc.id})")
                
                # Read the markdown content from the file
                with open(doc.markdown_filepath, 'r', encoding='utf-8') as f:
                    markdown_content = f.read()
                
                # Call the classifier agent
                classification = classifier.classify(markdown_content)
                
                # Update the document in the database
                updates = {
                    "document_type": classification.get("document_type"),
                    "document_grade": classification.get("document_grade"),
                    "ingestion_status": IngestionStatus.CLASSIFIED,
                    "error_message": None
                }
                db_handler.update_document(doc.id, updates)
                logger.info(f"Successfully classified document ID {doc.id}.")

            except Exception as e:
                logger.error(f"Error classifying document ID {doc.id}: {e}", exc_info=True)
                db_handler.update_document(
                    doc.id,
                    {"ingestion_status": IngestionStatus.FAILED, "error_message": f"Classification failed: {e}"}
                )

    finally:
        db_session.close()
        logger.info("--- Ingestion Pipeline Finished ---")


if __name__ == "__main__":
    logger.info("Application started.")
    
    # Ensure the database and tables are created before running the pipeline
    init_db()
    
    # Run the main processing function
    run_markdown_conversion_pipeline()
    
    logger.info("Application finished.")
# Out:
# c:\Users\omars\Documents\UST\Cogstate-RFI\.venv\Lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# 2025-07-22 13:31:37,004 - __main__ - INFO - Application started.
# 2025-07-22 13:31:37,005 - rfiprocessor.db.database - INFO - Initializing database and creating tables if they don't exist...
# 2025-07-22 13:31:37,012 - rfiprocessor.db.database - INFO - Database initialization complete.
# 2025-07-22 13:31:37,014 - __main__ - INFO - --- Starting Markdown Conversion Pipeline ---
# 2025-07-22 13:31:38,496 - rfiprocessor.services.llm_provider - INFO - Initialized Fast LLM Provider: gpt-4-turbo
# 2025-07-22 13:31:38,498 - rfiprocessor.services.prompt_loader - INFO - Loading prompt 'document_classifier' from: rfiprocessor\prompts\document_classifier.txt
# 2025-07-22 13:31:38,511 - rfiprocessor.core.agents.document_classifier - INFO - DocumentClassifierAgent initialized successfully.
# 2025-07-22 13:31:38,513 - rfiprocessor.utils.wlak_dir - DEBUG - Found file: data/raw/incoming\.DS_Store
# 2025-07-22 13:31:38,514 - rfiprocessor.utils.wlak_dir - DEBUG - Found file: data/raw/incoming\Cogstate Quality Management System_Quality Questionnaire Blank.pdf
# 2025-07-22 13:31:38,515 - rfiprocessor.utils.wlak_dir - DEBUG - Found file: data/raw/incoming\Diligent Pharma - Harmony Biosciences Core RFI 3.0 - 27-01-2025 Blank.xlsx
# 2025-07-22 13:31:38,516 - rfiprocessor.utils.wlak_dir - DEBUG - Found file: data/raw/incoming\LEXEO GCP service provider audit questionnaire Blank.docx
# 2025-07-22 13:31:38,518 - __main__ - INFO - Found 4 files. Registering new files in the database...
# 2025-07-22 13:31:38,539 - rfiprocessor.services.db_handler - INFO - Added new document '.DS_Store' to database with ID 11.
# 2025-07-22 13:31:38,547 - rfiprocessor.services.db_handler - INFO - Added new document 'Cogstate Quality Management System_Quality Questionnaire Blank.pdf' to database with ID 12.
# 2025-07-22 13:31:38,553 - rfiprocessor.services.db_handler - INFO - Added new document 'Diligent Pharma - Harmony Biosciences Core RFI 3.0 - 27-01-2025 Blank.xlsx' to database with ID 13.
# 2025-07-22 13:31:38,561 - rfiprocessor.services.db_handler - INFO - Added new document 'LEXEO GCP service provider audit questionnaire Blank.docx' to database with ID 14.
# 2025-07-22 13:31:38,563 - rfiprocessor.services.db_handler - DEBUG - Querying for documents with status: PENDING
# 2025-07-22 13:31:38,566 - __main__ - INFO - Found 3 new documents to process.
# Converting files to Markdown:   0%|          | 0/3 [00:00<?, ?it/s]2025-07-22 13:31:38,602 - __main__ - INFO - Processing document: Cogstate Quality Management System_Quality Questionnaire Blank.pdf (ID: 12)
# 2025-07-22 13:31:38,602 - rfiprocessor.services.markdown_converter - INFO - Converting file: data/raw/incoming\Cogstate Quality Management System_Quality Questionnaire Blank.pdf with markitdown
# 2025-07-22 13:31:39,208 - rfiprocessor.services.markdown_converter - INFO - Saved markdown to: data\markdown\incoming\Cogstate Quality Management System_Quality Questionnaire Blank.md
# 2025-07-22 13:31:39,215 - rfiprocessor.services.db_handler - INFO - Updating document ID 12 with: {'markdown_filepath': 'data\\markdown\\incoming\\Cogstate Quality Management System_Quality Questionnaire Blank.md', 'processed_filepath': 'data/raw/processed\\Cogstate Quality Management System_Quality Questionnaire Blank.pdf', 'ingestion_status': <IngestionStatus.MARKDOWN_CONVERTED: 'MARKDOWN_CONVERTED'>, 'error_message': None}
# 2025-07-22 13:31:39,223 - __main__ - INFO - Successfully converted and moved document ID 12.
# Converting files to Markdown:  33%|███▎      | 1/3 [00:00<00:01,  1.61it/s]2025-07-22 13:31:39,228 - __main__ - INFO - Processing document: Diligent Pharma - Harmony Biosciences Core RFI 3.0 - 27-01-2025 Blank.xlsx (ID: 13)
# 2025-07-22 13:31:39,230 - rfiprocessor.services.markdown_converter - INFO - Converting file: data/raw/incoming\Diligent Pharma - Harmony Biosciences Core RFI 3.0 - 27-01-2025 Blank.xlsx with unstructured
# 2025-07-22 13:31:39,785 - rfiprocessor.services.markdown_converter - ERROR - Unstructured processing failed: No module named 'msoffcrypto'
# 2025-07-22 13:31:39,787 - rfiprocessor.services.markdown_converter - ERROR - Conversion failed: No module named 'msoffcrypto'
# 2025-07-22 13:31:39,787 - __main__ - ERROR - Error processing document ID 13 ('Diligent Pharma - Harmony Biosciences Core RFI 3.0 - 27-01-2025 Blank.xlsx'): No module named 'msoffcrypto'
# Traceback (most recent call last):
#   File "C:\Users\omars\AppData\Local\Temp\ipykernel_108484\3934356070.py", line 74, in run_markdown_conversion_pipeline
#     markdown_content, markdown_path = converter.convert_to_markdown(
#                                       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         file_path=doc.source_filepath,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         processor=processor_to_use
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\Cogstate-RFI\rfiprocessor\services\markdown_converter.py", line 46, in convert_to_markdown
#     markdown_content = self._process_with_unstructured(file_path)
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\Cogstate-RFI\rfiprocessor\services\markdown_converter.py", line 74, in _process_with_unstructured
#     elements = partition(file_path)
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\.venv\Lib\site-packages\unstructured\partition\auto.py", line 291, in partition
#     partition = partitioner_loader.get(file_type)
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\.venv\Lib\site-packages\unstructured\partition\auto.py", line 364, in get
#     self._partitioners[file_type] = self._load_partitioner(file_type)
#                                     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\.venv\Lib\site-packages\unstructured\partition\auto.py", line 382, in _load_partitioner
#     partitioner_module = importlib.import_module(file_type.partitioner_module_qname)
#   File "C:\Program Files\Python313\Lib\importlib\__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 1026, in exec_module
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\.venv\Lib\site-packages\unstructured\partition\xlsx.py", line 11, in <module>
#     from msoffcrypto import OfficeFile
# ModuleNotFoundError: No module named 'msoffcrypto'
# 2025-07-22 13:31:39,884 - rfiprocessor.services.db_handler - INFO - Updating document ID 13 with: {'ingestion_status': <IngestionStatus.FAILED: 'FAILED'>, 'error_message': "No module named 'msoffcrypto'"}
# Converting files to Markdown:  67%|██████▋   | 2/3 [00:01<00:00,  1.54it/s]2025-07-22 13:31:39,893 - __main__ - INFO - Processing document: LEXEO GCP service provider audit questionnaire Blank.docx (ID: 14)
# 2025-07-22 13:31:39,895 - rfiprocessor.services.markdown_converter - INFO - Converting file: data/raw/incoming\LEXEO GCP service provider audit questionnaire Blank.docx with markitdown
# 2025-07-22 13:31:41,808 - rfiprocessor.services.markdown_converter - INFO - Saved markdown to: data\markdown\incoming\LEXEO GCP service provider audit questionnaire Blank.md
# 2025-07-22 13:31:41,814 - rfiprocessor.services.db_handler - INFO - Updating document ID 14 with: {'markdown_filepath': 'data\\markdown\\incoming\\LEXEO GCP service provider audit questionnaire Blank.md', 'processed_filepath': 'data/raw/processed\\LEXEO GCP service provider audit questionnaire Blank.docx', 'ingestion_status': <IngestionStatus.MARKDOWN_CONVERTED: 'MARKDOWN_CONVERTED'>, 'error_message': None}
# 2025-07-22 13:31:41,821 - __main__ - INFO - Successfully converted and moved document ID 14.
# Converting files to Markdown: 100%|██████████| 3/3 [00:03<00:00,  1.07s/it]
# 2025-07-22 13:31:41,823 - __main__ - INFO - --- Markdown Conversion Pipeline Finished ---
# 2025-07-22 13:31:41,824 - __main__ - INFO - --- Starting Document Classification Step ---
# 2025-07-22 13:31:41,824 - rfiprocessor.services.db_handler - DEBUG - Querying for documents with status: MARKDOWN_CONVERTED
# 2025-07-22 13:31:41,828 - __main__ - INFO - Found 2 documents to classify.
# Classifying documents:   0%|          | 0/2 [00:00<?, ?it/s]2025-07-22 13:31:41,831 - __main__ - INFO - Classifying document: Cogstate Quality Management System_Quality Questionnaire Blank.pdf (ID: 12)
# 2025-07-22 13:31:41,848 - rfiprocessor.core.agents.document_classifier - INFO - Attempting to classify document...
# 2025-07-22 13:31:44,016 - rfiprocessor.core.agents.document_classifier - DEBUG - LLM raw response for classification: {
#   "document_type": "RFI/RFP",
#   "document_grade": "Past Response"
# }
# 2025-07-22 13:31:44,017 - rfiprocessor.core.agents.document_classifier - INFO - Document classified successfully as: {'document_type': 'RFI/RFP', 'document_grade': 'Past Response'}
# 2025-07-22 13:31:44,019 - rfiprocessor.services.db_handler - INFO - Updating document ID 12 with: {'document_type': 'RFI/RFP', 'document_grade': 'Past Response', 'ingestion_status': <IngestionStatus.CLASSIFIED: 'CLASSIFIED'>, 'error_message': None}
# 2025-07-22 13:31:44,026 - __main__ - INFO - Successfully classified document ID 12.
# Classifying documents:  50%|█████     | 1/2 [00:02<00:02,  2.20s/it]2025-07-22 13:31:44,029 - __main__ - INFO - Classifying document: LEXEO GCP service provider audit questionnaire Blank.docx (ID: 14)
# 2025-07-22 13:31:44,041 - rfiprocessor.core.agents.document_classifier - INFO - Attempting to classify document...
# 2025-07-22 13:31:45,712 - rfiprocessor.core.agents.document_classifier - DEBUG - LLM raw response for classification: {
#   "document_type": "RFI/RFP",
#   "document_grade": "Past Response"
# }
# 2025-07-22 13:31:45,713 - rfiprocessor.core.agents.document_classifier - INFO - Document classified successfully as: {'document_type': 'RFI/RFP', 'document_grade': 'Past Response'}
# 2025-07-22 13:31:45,715 - rfiprocessor.services.db_handler - INFO - Updating document ID 14 with: {'document_type': 'RFI/RFP', 'document_grade': 'Past Response', 'ingestion_status': <IngestionStatus.CLASSIFIED: 'CLASSIFIED'>, 'error_message': None}
# 2025-07-22 13:31:45,720 - __main__ - INFO - Successfully classified document ID 14.
# Classifying documents: 100%|██████████| 2/2 [00:03<00:00,  1.94s/it]
# 2025-07-22 13:31:45,722 - __main__ - INFO - --- Ingestion Pipeline Finished ---
# 2025-07-22 13:31:45,722 - __main__ - INFO - Application finished.

# %%
from tqdm import tqdm

# --- Core Application Imports ---
from config.config import Config
from rfiprocessor.utils.logger import get_logger
from rfiprocessor.core.agents.document_classifier import DocumentClassifierAgent

# --- Database Imports ---
from rfiprocessor.db.database import init_db, get_db_session
from rfiprocessor.services.db_handler import DatabaseHandler
from rfiprocessor.db.db_models import IngestionStatus

# --- Initial Setup ---
config = Config()
logger = get_logger(__name__)

def run_document_classification_pipeline():
    """
    Scans for markdown_converted files, classify them to RFI/RFO or Supporting Document with grades, and tracks progress in the database.
    """

    classifier = DocumentClassifierAgent()

    # Get a database session and initialize the handler
    db_session_generator = get_db_session()
    db_session = next(db_session_generator)
    try:
        db_handler = DatabaseHandler(db_session)

        # --- Step 2: Document Classification ---
        logger.info("--- Starting Document Classification Step ---")
        docs_to_classify = db_handler.get_documents_by_status(IngestionStatus.MARKDOWN_CONVERTED)

        if not docs_to_classify:
            logger.info("No new documents to classify.")
        else:
            logger.info(f"Found {len(docs_to_classify)} documents to classify.")

        for doc in tqdm(docs_to_classify, desc="Classifying documents"):
            try:
                logger.info(f"Classifying document: {doc.source_filename} (ID: {doc.id})")
                
                # Read the markdown content from the file
                with open(doc.markdown_filepath, 'r', encoding='utf-8') as f:
                    markdown_content = f.read()
                
                # Call the classifier agent
                classification = classifier.classify(markdown_content)
                
                # Update the document in the database
                updates = {
                    "document_type": classification.get("document_type"),
                    "document_grade": classification.get("document_grade"),
                    "ingestion_status": IngestionStatus.CLASSIFIED,
                    "error_message": None
                }
                db_handler.update_document(doc.id, updates)
                logger.info(f"Successfully classified document ID {doc.id}.")

            except Exception as e:
                logger.error(f"Error classifying document ID {doc.id}: {e}", exc_info=True)
                db_handler.update_document(
                    doc.id,
                    {"ingestion_status": IngestionStatus.FAILED, "error_message": f"Classification failed: {e}"}
                )

    finally:
        db_session.close()
        logger.info("--- Ingestion Pipeline Finished ---")

if __name__ == "__main__":
    logger.info("Application started.")
    
    # Ensure the database and tables are created before running the pipeline
    init_db()
    
    # Run the main processing function
    run_document_classification_pipeline()
    
    logger.info("Application finished.")
# Out:
# 2025-07-22 13:31:45,738 - __main__ - INFO - Application started.
# 2025-07-22 13:31:45,740 - rfiprocessor.db.database - INFO - Initializing database and creating tables if they don't exist...
# 2025-07-22 13:31:45,743 - rfiprocessor.db.database - INFO - Database initialization complete.
# 2025-07-22 13:31:45,746 - rfiprocessor.services.llm_provider - INFO - Initialized Fast LLM Provider: gpt-4-turbo
# 2025-07-22 13:31:45,747 - rfiprocessor.services.prompt_loader - DEBUG - Returning cached prompt: 'document_classifier'
# 2025-07-22 13:31:45,749 - rfiprocessor.core.agents.document_classifier - INFO - DocumentClassifierAgent initialized successfully.
# 2025-07-22 13:31:45,749 - __main__ - INFO - --- Starting Document Classification Step ---
# 2025-07-22 13:31:45,750 - rfiprocessor.services.db_handler - DEBUG - Querying for documents with status: MARKDOWN_CONVERTED
# 2025-07-22 13:31:45,752 - __main__ - INFO - No new documents to classify.
# Classifying documents: 0it [00:00, ?it/s]
# 2025-07-22 13:31:45,755 - __main__ - INFO - --- Ingestion Pipeline Finished ---
# 2025-07-22 13:31:45,756 - __main__ - INFO - Application finished.

# %%
from tqdm import tqdm
from pydantic import ValidationError

# --- Core Application Imports ---
from config.config import Config
from rfiprocessor.utils.logger import get_logger
from rfiprocessor.core.agents.rfi_parser import RfiParserAgent

# --- Database Imports ---
from rfiprocessor.db.database import init_db, get_db_session
from rfiprocessor.services.db_handler import DatabaseHandler
from rfiprocessor.db.db_models import IngestionStatus
from rfiprocessor.models.data_models import RFIJson

import os
import json

# --- Initial Setup ---
config = Config()
logger = get_logger(__name__)

def run_rfi_parser_pipeline():
    """
    Scans for classified RFI/RFP files and processes them through the RFI parser pipeline.
    """
    logger.info("--- Starting RFI Parsing Pipeline ---")
    rfi_parser = RfiParserAgent()
    
    db_session_generator = get_db_session()
    db_session = next(db_session_generator)
    try:
        db_handler = DatabaseHandler(db_session)

        # --- Step 3: RFI/RFP Parsing ---
        logger.info("--- Starting RFI/RFP Parsing Step ---")
        docs_to_parse = db_handler.get_documents_by_status(IngestionStatus.CLASSIFIED)

        if not docs_to_parse:
            logger.info("No new classified documents to parse.")
        else:
            logger.info(f"Found {len(docs_to_parse)} documents to potentially parse.")

        for doc in tqdm(docs_to_parse, desc="Parsing RFI/RFP documents"):
            try:
                # Only process documents that were classified as RFI/RFP
                if doc.document_type != "RFI/RFP":
                    logger.info(f"Skipping parsing for doc ID {doc.id} (type: {doc.document_type}). Marking as parsed.")
                    db_handler.update_document(doc.id, {"ingestion_status": IngestionStatus.PARSED})
                    continue

                logger.info(f"Parsing RFI/RFP document: {doc.source_filename} (ID: {doc.id})")
                
                # Read the markdown content
                with open(doc.markdown_filepath, 'r', encoding='utf-8') as f:
                    markdown_content = f.read()
                
                # Call the RFI Parser Agent
                parsed_data = rfi_parser.parse(markdown_content)
                
                # --- SAVE TO /json_output FOLDER AT PROJECT ROOT ---
                output_dir = "json_output"
                os.makedirs(output_dir, exist_ok=True)
                json_filename = os.path.splitext(doc.source_filename)[0] + ".json"
                output_path = os.path.join(output_dir, json_filename)
                with open(output_path, "w", encoding="utf-8") as f:
                    json.dump(parsed_data, f, indent=2, ensure_ascii=False)
                logger.info(f"Saved parsed output to {output_path}")
                # --- END SAVE SECTION ---

                # Validate the structured output with Pydantic
                try:
                    validated_data = RFIJson.model_validate(parsed_data)
                    logger.info(f"Successfully validated JSON structure for doc ID {doc.id}.")
                except ValidationError as ve:
                    # If validation fails, log the specific error and mark the doc as failed
                    error_details = f"Pydantic validation failed for doc ID {doc.id}: {ve}"
                    logger.error(error_details)
                    db_handler.update_document(
                        doc.id,
                        {"ingestion_status": IngestionStatus.FAILED, "error_message": error_details}
                    )
                    continue  # Skip to the next document
                
                # Update the document record with the JSON payload and new status
                updates = {
                    "rfi_json_payload": validated_data.model_dump(),  # Use the validated data
                    "ingestion_status": IngestionStatus.PARSED,
                    "error_message": None
                }
                db_handler.update_document(doc.id, updates)
                logger.info(f"Successfully parsed and stored JSON for document ID {doc.id}.")

            except Exception as e:
                error_msg = f"Error parsing document ID {doc.id}: {e}"
                logger.error(error_msg, exc_info=True)
                db_handler.update_document(
                    doc.id,
                    {"ingestion_status": IngestionStatus.FAILED, "error_message": error_msg}
                )

    finally:
        db_session.close()
        logger.info("--- Ingestion Pipeline Finished ---")

# The if __name__ == "__main__": block remains the same
if __name__ == "__main__":
    logger.info("Application started.")
    init_db()
    run_rfi_parser_pipeline()
    logger.info("Application finished.")
# Out:
# 2025-07-22 13:31:45,782 - __main__ - INFO - Application started.
# 2025-07-22 13:31:45,783 - rfiprocessor.db.database - INFO - Initializing database and creating tables if they don't exist...
# 2025-07-22 13:31:45,784 - rfiprocessor.db.database - INFO - Database initialization complete.
# 2025-07-22 13:31:45,785 - __main__ - INFO - --- Starting RFI Parsing Pipeline ---
# 2025-07-22 13:31:46,303 - rfiprocessor.services.llm_provider - INFO - Initialized Advanced LLM Provider: gpt-4o
# 2025-07-22 13:31:46,305 - rfiprocessor.services.prompt_loader - INFO - Loading prompt 'rfi_parser_summary' from: rfiprocessor\prompts\rfi_parser_summary.txt
# 2025-07-22 13:31:46,319 - rfiprocessor.services.prompt_loader - INFO - Loading prompt 'rfi_parser_chunking' from: rfiprocessor\prompts\rfi_parser_chunking.txt
# 2025-07-22 13:31:46,337 - rfiprocessor.core.agents.rfi_parser - INFO - RfiParserAgent initialized successfully.
# 2025-07-22 13:31:46,338 - __main__ - INFO - --- Starting RFI/RFP Parsing Step ---
# 2025-07-22 13:31:46,339 - rfiprocessor.services.db_handler - DEBUG - Querying for documents with status: CLASSIFIED
# 2025-07-22 13:31:46,340 - __main__ - INFO - Found 2 documents to potentially parse.
# Parsing RFI/RFP documents:   0%|          | 0/2 [00:00<?, ?it/s]2025-07-22 13:31:46,343 - __main__ - INFO - Parsing RFI/RFP document: Cogstate Quality Management System_Quality Questionnaire Blank.pdf (ID: 12)
# 2025-07-22 13:31:46,345 - rfiprocessor.core.agents.rfi_parser - INFO - Generating executive summary...
# 2025-07-22 13:32:18,616 - rfiprocessor.core.agents.rfi_parser - INFO - Splitting document into processable chunks...
# 2025-07-22 13:32:18,618 - rfiprocessor.core.agents.rfi_parser - INFO - Processing 5 chunks concurrently...
# 2025-07-22 13:32:18,619 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# AbbVie R&D QA
# Supplier Assessment Quality Questionnaire
#
# Greetings,
#
# The purpose of this Quality Questionnaire (QQ) is to obtain a comprehensive understanding
# of the business practices, procedures, and quality systems currently in place at your
# company. Please ensure you respond to all questions and indicate N/A where appropriate. If
# any question requires additional space, please attach a supplemental page.
#
# All responses to this questionnaire are treated as highly confidential and will solely be utilized
# by AbbVie Quality Assurance (QA) Representatives as an assessment tool.
#
# To facilitate the assessment process, we ask that following documents be provided with the
# completed QQ:
#
#   Quality Manual☐ N/A
#   Quality Policy ☐ N/A
#   Organizational Charts ☐ N/A
#   SOP/Policies/Work Instruction Indices, including titles and effective dates ☐ N/A
#   Copies of current licenses, registrations, certifications, and/or accreditations ☐ N/A
#   Listing of equipment and instruments used and/or maint...
# --- END OF CHUNK ---
#
# --- Logging error ---
# 2025-07-22 13:32:18,623 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# nd whether observations/violations were issued.
# Note: Provide a copy of any notices regarding significant regulatory violations and redacted observations, if
# applicable.
#
# A9. Audited/Inspected by any of the following Certification or Accreditation agencies: International Standards
# Organization (ISO), National Research Council (NRC), Clinical Laboratory Improvement Amendments (CLIA),
# Accreditation of Human Research Protection Programs (AAHRPP), or other agency?
# ☐ Yes ☐ No
# If yes, list the agency and any associated details.
#
# A10. Would your company be receptive to an onsite or remote audit by AbbVie QA Representatives?
# ☐ Yes ☐ No ☐ N/A
#
# Page 3 of 13
#
# AbbVie R&D QA
# Supplier Assessment Quality Questionnaire
#
# A11. Does your company have a Quality Organization? ☐ Yes  ☐ No
# If yes, how many employees are in your Quality Organization?
# If no, provide an explanation.
#
# A12. Does your company have a defined Quality Policy for ensuring quality in the services provided? ☐ Yes  ☐ No
# If yes, referenc...
# --- END OF CHUNK ---
#
# 2025-07-22 13:32:18,624 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# no, provide an explanation.
#
# F)  Documentation of training, including On the Job training? ☐Yes ☐No
#
# If no, provide an explanation.
#
# A26. Do all employees performing regulated activities/services receive annual refresher training on the applicable GxP
# Guidelines? ☐Yes ☐No
#
# A27. Are all procedures, forms, and electronic systems readily available to all employees performing activities related
# to the services provided? ☐ Yes  ☐ No
#
# A28. Will any contract employees be performing activities related to the services provided?
# ☐ Yes  ☐ No
# If yes, explain how the contractor is properly trained and qualified to provide services on behalf of your company.
#
# Page 6 of 13
#
# AbbVie R&D QA
# Supplier Assessment Quality Questionnaire
#
# DOCUMENTATION:
#
# A29. Does your company have a process and written procedures for establishing and maintaining control of quality
# documents and records? ☐ Yes  ☐ No
# If yes, list applicable procedures.
#
# A30. Are quality documents controlled by revision and/or date? ☐ Yes  ☐ N...
# --- END OF CHUNK ---
#
# 2025-07-22 13:32:18,628 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# and
# audit outcomes? ☐ Yes ☐ No
# If yes, list applicable procedures.
#
# A45. Does the CAPA procedure include the following:
#
# A)  Evaluation of Risk? ☐ Yes ☐ No
# B)  Root Cause Analysis? ☐ Yes ☐ No
# C)  Impact on Data? ☐ Yes ☐ No
# D)  Escalation Process? ☐ Yes ☐ No
# E)  Effectiveness Check? ☐ Yes ☐ No
#
# A46. Does the Quality Organization review and approve exception documentation? ☐ Yes  ☐ No
#
# A47. Is there a provision to notify the customer in a timely manner and/or request a deviation from requirements or
# protocols? ☐ Yes  ☐ No
#
# A48. Is there a process for tracking and trending CAPA issues and exceptions? ☐ Yes  ☐ No
#
# A49. Are exceptions and/or CAPAs part of the agenda for Management Review? ☐ Yes  ☐ No
#
# CHANGE MANAGEMENT:
#
# A50. Does your company have a change management process and written procedures for change control?
# ☐ Yes  ☐ No
# If yes, list applicable procedures.
# If no, explain how consistency and compliance is maintained for changes that could impact services and quality.
#
# A51. Does the ...
# --- END OF CHUNK ---
#
# 2025-07-22 13:32:18,628 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# tor, reviewer) clearly defined with appropriately assigned rights
# and permissions? ☐ Yes  ☐ No
#
# A67. Are activities performed attributable to a specific user? ☐ Yes  ☐ No
#
# A68. Are changes to records prohibited except by authorized users? ☐ Yes  ☐ No
#
# A69. Are Good Documentation Practices followed for changes to records and data, including electronic records?
# ☐ Yes  ☐ No
#
# A70. Are audit trails enabled to allow for reconstruction of the course of events relating to the creation, modification,
# or deletion of an electronic record? ☐ Yes  ☐ No
#
# A71. Are records reviewed for accuracy, completeness, and compliance with established procedures and regulations?
# ☐ Yes  ☐ No
#
# Page 11 of 13
#
# AbbVie R&D QA
# Supplier Assessment Quality Questionnaire
#
# A72. Is data maintained securely from the time of creation through disposition after the record’s retention period?
# ☐ Yes  ☐ No
#
# A73. Does audit trail review for electronic data and the frequency with which it's conducted ensure that regulatory
# requirem...
# --- END OF CHUNK ---
#
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\uf0b7' in position 832: character maps to <undefined>
# Call stack:
#   File "C:\Program Files\Python313\Lib\threading.py", line 1012, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Program Files\Python313\Lib\concurrent\futures\thread.py", line 93, in _worker
#     work_item.run()
#   File "C:\Program Files\Python313\Lib\concurrent\futures\thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\Cogstate-RFI\rfiprocessor\core\agents\rfi_parser.py", line 148, in process_one_chunk
#     chunk_data = self._safe_convert_chunk(chunk)
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\Cogstate-RFI\rfiprocessor\core\agents\rfi_parser.py", line 102, in _safe_convert_chunk
#     logger.info("\n--- CHUNK SENT TO LLM ---\n" + chunk_text[:1000] + ("..." if len(chunk_text) > 1000 else "") + "\n--- END OF CHUNK ---\n")
# Message: '\n--- CHUNK SENT TO LLM ---\nAbbVie R&D QA\nSupplier Assessment Quality Questionnaire\n\nGreetings,\n\nThe purpose of this Quality Questionnaire (QQ) is to obtain a comprehensive understanding\nof the business practices, procedures, and quality systems currently in place at your\ncompany. Please ensure you respond to all questions and indicate N/A where appropriate. If\nany question requires additional space, please attach a supplemental page.\n\nAll responses to this questionnaire are treated as highly confidential and will solely be utilized\nby AbbVie Quality Assurance (QA) Representatives as an assessment tool.\n\nTo facilitate the assessment process, we ask that following documents be provided with the\ncompleted QQ:\n\n\uf0b7  Quality Manual☐ N/A\n\uf0b7  Quality Policy ☐ N/A\n\uf0b7  Organizational Charts ☐ N/A\n\uf0b7  SOP/Policies/Work Instruction Indices, including titles and effective dates ☐ N/A\n\uf0b7  Copies of current licenses, registrations, certifications, and/or accreditations ☐ N/A\n\uf0b7  Listing of equipment and instruments used and/or maint...\n--- END OF CHUNK ---\n'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2610' in position 598: character maps to <undefined>
# Call stack:
#   File "C:\Program Files\Python313\Lib\threading.py", line 1012, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Program Files\Python313\Lib\concurrent\futures\thread.py", line 93, in _worker
#     work_item.run()
#   File "C:\Program Files\Python313\Lib\concurrent\futures\thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\Cogstate-RFI\rfiprocessor\core\agents\rfi_parser.py", line 148, in process_one_chunk
#     chunk_data = self._safe_convert_chunk(chunk)
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\Cogstate-RFI\rfiprocessor\core\agents\rfi_parser.py", line 102, in _safe_convert_chunk
#     logger.info("\n--- CHUNK SENT TO LLM ---\n" + chunk_text[:1000] + ("..." if len(chunk_text) > 1000 else "") + "\n--- END OF CHUNK ---\n")
# Message: '\n--- CHUNK SENT TO LLM ---\nnd whether observations/violations were issued.\nNote: Provide a copy of any notices regarding significant regulatory violations and redacted observations, if\napplicable.\n\nA9. Audited/Inspected by any of the following Certification or Accreditation agencies: International Standards\nOrganization (ISO), National Research Council (NRC), Clinical Laboratory Improvement Amendments (CLIA),\nAccreditation of Human Research Protection Programs (AAHRPP), or other agency?\n☐ Yes ☐ No\nIf yes, list the agency and any associated details.\n\nA10. Would your company be receptive to an onsite or remote audit by AbbVie QA Representatives?\n☐ Yes ☐ No ☐ N/A\n\nPage 3 of 13\n\n\x0cAbbVie R&D QA\nSupplier Assessment Quality Questionnaire\n\nA11. Does your company have a Quality Organization? ☐ Yes  ☐ No\nIf yes, how many employees are in your Quality Organization?\nIf no, provide an explanation.\n\nA12. Does your company have a defined Quality Policy for ensuring quality in the services provided? ☐ Yes  ☐ No\nIf yes, referenc...\n--- END OF CHUNK ---\n'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2610' in position 219: character maps to <undefined>
# Call stack:
#   File "C:\Program Files\Python313\Lib\threading.py", line 1012, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Program Files\Python313\Lib\concurrent\futures\thread.py", line 93, in _worker
#     work_item.run()
#   File "C:\Program Files\Python313\Lib\concurrent\futures\thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\Cogstate-RFI\rfiprocessor\core\agents\rfi_parser.py", line 148, in process_one_chunk
#     chunk_data = self._safe_convert_chunk(chunk)
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\Cogstate-RFI\rfiprocessor\core\agents\rfi_parser.py", line 102, in _safe_convert_chunk
#     logger.info("\n--- CHUNK SENT TO LLM ---\n" + chunk_text[:1000] + ("..." if len(chunk_text) > 1000 else "") + "\n--- END OF CHUNK ---\n")
# Message: '\n--- CHUNK SENT TO LLM ---\nno, provide an explanation.\n\nF)  Documentation of training, including On the Job training? ☐Yes ☐No\n\nIf no, provide an explanation.\n\nA26. Do all employees performing regulated activities/services receive annual refresher training on the applicable GxP\nGuidelines? ☐Yes ☐No\n\nA27. Are all procedures, forms, and electronic systems readily available to all employees performing activities related\nto the services provided? ☐ Yes  ☐ No\n\nA28. Will any contract employees be performing activities related to the services provided?\n☐ Yes  ☐ No\nIf yes, explain how the contractor is properly trained and qualified to provide services on behalf of your company.\n\nPage 6 of 13\n\n\x0cAbbVie R&D QA\nSupplier Assessment Quality Questionnaire\n\nDOCUMENTATION:\n\nA29. Does your company have a process and written procedures for establishing and maintaining control of quality\ndocuments and records? ☐ Yes  ☐ No\nIf yes, list applicable procedures.\n\nA30. Are quality documents controlled by revision and/or date? ☐ Yes  ☐ N...\n--- END OF CHUNK ---\n'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2610' in position 147: character maps to <undefined>
# Call stack:
#   File "C:\Program Files\Python313\Lib\threading.py", line 1012, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Program Files\Python313\Lib\concurrent\futures\thread.py", line 93, in _worker
#     work_item.run()
#   File "C:\Program Files\Python313\Lib\concurrent\futures\thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\Cogstate-RFI\rfiprocessor\core\agents\rfi_parser.py", line 148, in process_one_chunk
#     chunk_data = self._safe_convert_chunk(chunk)
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\Cogstate-RFI\rfiprocessor\core\agents\rfi_parser.py", line 102, in _safe_convert_chunk
#     logger.info("\n--- CHUNK SENT TO LLM ---\n" + chunk_text[:1000] + ("..." if len(chunk_text) > 1000 else "") + "\n--- END OF CHUNK ---\n")
# Message: '\n--- CHUNK SENT TO LLM ---\nand\naudit outcomes? ☐ Yes ☐ No\nIf yes, list applicable procedures.\n\nA45. Does the CAPA procedure include the following:\n\nA)  Evaluation of Risk? ☐ Yes ☐ No\nB)  Root Cause Analysis? ☐ Yes ☐ No\nC)  Impact on Data? ☐ Yes ☐ No\nD)  Escalation Process? ☐ Yes ☐ No\nE)  Effectiveness Check? ☐ Yes ☐ No\n\nA46. Does the Quality Organization review and approve exception documentation? ☐ Yes  ☐ No\n\nA47. Is there a provision to notify the customer in a timely manner and/or request a deviation from requirements or\nprotocols? ☐ Yes  ☐ No\n\nA48. Is there a process for tracking and trending CAPA issues and exceptions? ☐ Yes  ☐ No\n\nA49. Are exceptions and/or CAPAs part of the agenda for Management Review? ☐ Yes  ☐ No\n\nCHANGE MANAGEMENT:\n\nA50. Does your company have a change management process and written procedures for change control?\n☐ Yes  ☐ No\nIf yes, list applicable procedures.\nIf no, explain how consistency and compliance is maintained for changes that could impact services and quality.\n\nA51. Does the ...\n--- END OF CHUNK ---\n'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Program Files\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2610' in position 210: character maps to <undefined>
# Call stack:
#   File "C:\Program Files\Python313\Lib\threading.py", line 1012, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\Program Files\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Program Files\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Program Files\Python313\Lib\concurrent\futures\thread.py", line 93, in _worker
#     work_item.run()
#   File "C:\Program Files\Python313\Lib\concurrent\futures\thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\Cogstate-RFI\rfiprocessor\core\agents\rfi_parser.py", line 148, in process_one_chunk
#     chunk_data = self._safe_convert_chunk(chunk)
#   File "c:\Users\omars\Documents\UST\Cogstate-RFI\Cogstate-RFI\rfiprocessor\core\agents\rfi_parser.py", line 102, in _safe_convert_chunk
#     logger.info("\n--- CHUNK SENT TO LLM ---\n" + chunk_text[:1000] + ("..." if len(chunk_text) > 1000 else "") + "\n--- END OF CHUNK ---\n")
# Message: "\n--- CHUNK SENT TO LLM ---\ntor, reviewer) clearly defined with appropriately assigned rights\nand permissions? ☐ Yes  ☐ No\n\nA67. Are activities performed attributable to a specific user? ☐ Yes  ☐ No\n\nA68. Are changes to records prohibited except by authorized users? ☐ Yes  ☐ No\n\nA69. Are Good Documentation Practices followed for changes to records and data, including electronic records?\n☐ Yes  ☐ No\n\nA70. Are audit trails enabled to allow for reconstruction of the course of events relating to the creation, modification,\nor deletion of an electronic record? ☐ Yes  ☐ No\n\nA71. Are records reviewed for accuracy, completeness, and compliance with established procedures and regulations?\n☐ Yes  ☐ No\n\nPage 11 of 13\n\n\x0cAbbVie R&D QA\nSupplier Assessment Quality Questionnaire\n\nA72. Is data maintained securely from the time of creation through disposition after the record’s retention period?\n☐ Yes  ☐ No\n\nA73. Does audit trail review for electronic data and the frequency with which it's conducted ensure that regulatory\nrequirem...\n--- END OF CHUNK ---\n"
# Arguments: ()
# 2025-07-22 13:32:30,067 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': '', 'description': 'AbbVie R&D QA Supplier Assessment Quality Questionnaire', 'qa_pairs': [{'question': 'Are activities performed attributable to a specific user?', 'answer': '', 'domain': 'Security', 'type': 'close-ended'}, {'question': 'Are changes to records prohibited except by authorized users?', 'answer': '', 'domain': 'Security', 'type': 'close-ended'}, {'question': 'Are Good Documentation Practices followed for changes to records and data, including electronic records?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Are audit trails enabled to allow for reconstruction of the course of events relating to the creation, modification, or deletion of an electronic record?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Are records reviewed for accuracy, completeness, and compliance with established procedures and regulations?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Is data maintained securely from the time of creation through disposition after the record’s retention period?', 'answer': '', 'domain': 'Security', 'type': 'close-ended'}, {'question': "Does audit trail review for electronic data and the frequency with which it's conducted ensure that regulatory requirements are met, appropriate change controls are implemented, and the reliability of the review is verified?", 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Are electronic source records retained even when printouts are used to present data?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Does your company have an established Disaster Recovery Plan (DRP)?', 'answer': '', 'domain': 'Business Continuity', 'type': 'close-ended'}, {'question': 'If no, provide an explanation.', 'answer': '', 'domain': 'Business Continuity', 'type': 'open-ended'}, {'question': 'If yes, does the plan include up to date contact information for Disaster Recovery service providers?', 'answer': '', 'domain': 'Business Continuity', 'type': 'close-ended'}, {'question': 'Provide the date of when the DRP was last reviewed.', 'answer': '', 'domain': 'Business Continuity', 'type': 'open-ended'}, {'question': 'Provide the date of when the DRP was last tested.', 'answer': '', 'domain': 'Business Continuity', 'type': 'open-ended'}, {'question': 'Does your company have an established Business Continuity Plan (BCP)?', 'answer': '', 'domain': 'Business Continuity', 'type': 'close-ended'}, {'question': 'If no, explain how the business will ensure they can restore operations in case of unforeseen events with minimal impact on the services provided.', 'answer': '', 'domain': 'Business Continuity', 'type': 'open-ended'}, {'question': 'If yes, does the plan include up to date contact information for Business Continuity service providers?', 'answer': '', 'domain': 'Business Continuity', 'type': 'close-ended'}, {'question': 'Provide the date of when the BCP was last reviewed.', 'answer': '', 'domain': 'Business Continuity', 'type': 'open-ended'}, {'question': 'Provide the date of when the BCP was last tested.', 'answer': '', 'domain': 'Business Continuity', 'type': 'open-ended'}], 'meta_data': {'company_name': 'AbbVie', 'date': 'N/A', 'category': 'RFP', 'type': 'PastResponse'}}
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 13:32:33,335 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': 'The purpose of this Quality Questionnaire (QQ) is to obtain a comprehensive understanding of the business practices, procedures, and quality systems currently in place at your company. Please ensure you respond to all questions and indicate N/A where appropriate. If any question requires additional space, please attach a supplemental page. All responses to this questionnaire are treated as highly confidential and will solely be utilized by AbbVie Quality Assurance (QA) Representatives as an assessment tool. To facilitate the assessment process, we ask that following documents be provided with the completed QQ: Quality Manual, Quality Policy, Organizational Charts, SOP/Policies/Work Instruction Indices, including titles and effective dates, Copies of current licenses, registrations, certifications, and/or accreditations, Listing of equipment and instruments used and/or maintained, if applicable. We kindly ask that you complete the Quality Questionnaire within 14 calendar days of receiving this request. Please do not hesitate to reach out for any questions regarding the assessment process. Thank you for your cooperation. AbbVie QA Representatives', 'description': "The Quality Questionnaire aims to gather detailed information about the company's quality systems and business practices. It includes questions about company structure, regulatory adherence, audits, and quality policies. Respondents are required to provide various documents such as Quality Manuals and Organizational Charts to support their responses.", 'qa_pairs': [{'question': 'Is your company a division or subsidiary of another corporation?', 'answer': '', 'domain': 'General', 'type': 'close-ended'}, {'question': 'Is the company address the location where services will be performed?', 'answer': '', 'domain': 'General', 'type': 'close-ended'}, {'question': 'Will any part of the services be sub-contracted to another provider?', 'answer': '', 'domain': 'General', 'type': 'close-ended'}, {'question': 'List any contracts and/or quality agreements that include quality oversight responsibilities for services to be provided.', 'answer': '', 'domain': 'General', 'type': 'open-ended'}, {'question': 'What regulatory guidelines does your company adhere to at its locations for the services it provides?', 'answer': '', 'domain': 'Compliance', 'type': 'open-ended'}, {'question': 'Does your company verify that it does not use, in any capacity, the services of any person on the FDA Debarment List or an equivalent for other International Authorities?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Has your company been audited or inspected in the past 2 years?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Audited/Inspected by any of the following Regulatory or Government agencies: Food and Drug Administration (FDA), European Medicines Agency (EMA), Medicines and Healthcare products Regulatory Agency (MHRA), or other agency?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Audited/Inspected by any of the following Certification or Accreditation agencies: International Standards Organization (ISO), National Research Council (NRC), Clinical Laboratory Improvement Amendments (CLIA), Accreditation of Human Research Protection Programs (AAHRPP), or other agency?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Would your company be receptive to an onsite or remote audit by AbbVie QA Representatives?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Does your company have a Quality Organization?', 'answer': '', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'Does your company have a defined Quality Policy for ensuring quality in the services provided?', 'answer': '', 'domain': 'Quality', 'type': 'close-ended'}], 'meta_data': {'company_name': 'AbbVie', 'date': 'N/A', 'category': 'RFI', 'type': 'PastResponse'}}
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 13:32:35,813 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': 'N/A', 'description': 'AbbVie R&D QA Supplier Assessment Quality Questionnaire', 'qa_pairs': [{'question': 'Audited/Inspected by any of the following Certification or Accreditation agencies: International Standards Organization (ISO), National Research Council (NRC), Clinical Laboratory Improvement Amendments (CLIA), Accreditation of Human Research Protection Programs (AAHRPP), or other agency?', 'answer': 'N/A', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Would your company be receptive to an onsite or remote audit by AbbVie QA Representatives?', 'answer': 'N/A', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Does your company have a Quality Organization?', 'answer': 'N/A', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'Does your company have a defined Quality Policy for ensuring quality in the services provided?', 'answer': 'N/A', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'Does your company have a Quality Manual that outlines the approach to quality?', 'answer': 'N/A', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'Does your company have a Quality Management System (QMS) in place to ensure quality in the execution of service-related activities?', 'answer': 'N/A', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'Does your QMS require written procedures to be approved and reviewed periodically by the Quality Organization?', 'answer': 'N/A', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'If your company has multiple locations, are all systems/policies/procedures utilized globally across the organization?', 'answer': 'N/A', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'Does your QMS include a Management Review process in which the effectiveness of the Quality System is reviewed by Executive Management?', 'answer': 'N/A', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'Does your QMS include an Internal Audit Program?', 'answer': 'N/A', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'Are internal audits conducted on a routine basis according to a documented and maintained schedule?', 'answer': 'N/A', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'Are corrective actions taken when any audit deficiencies are identified?', 'answer': 'N/A', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'Are audit outcomes for both internal and external/customer audits part of the agenda for Management Review?', 'answer': 'N/A', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'Describe the Quality System’s Risk Management process.', 'answer': 'N/A', 'domain': 'Quality', 'type': 'open-ended'}, {'question': 'Describe how risks are communicated to stakeholders (e.g., users, medical professionals, regulatory bodies, etc).', 'answer': 'N/A', 'domain': 'Quality', 'type': 'open-ended'}, {'question': 'Does your company have a written training program including procedures for execution and documentation of required training?', 'answer': 'N/A', 'domain': 'Training', 'type': 'close-ended'}, {'question': 'Does your company’s training program include the following: Approved job descriptions for all employees?', 'answer': 'N/A', 'domain': 'Training', 'type': 'close-ended'}, {'question': 'Does your company’s training program include the following: Management of current CVs?', 'answer': 'N/A', 'domain': 'Training', 'type': 'close-ended'}, {'question': 'Does your company’s training program include the following: Comprehensive training requirements for all job titles or functions?', 'answer': 'N/A', 'domain': 'Training', 'type': 'close-ended'}, {'question': 'Does your company’s training program include the following: Routine review of job descriptions, CVs, and training requirements of all job titles?', 'answer': 'N/A', 'domain': 'Training', 'type': 'close-ended'}, {'question': 'Does your company’s training program include the following: Regulatory training requirements?', 'answer': 'N/A', 'domain ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 13:32:39,425 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': '', 'description': '', 'qa_pairs': [{'question': 'Do you have audit outcomes?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Does the CAPA procedure include the evaluation of risk?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Does the CAPA procedure include root cause analysis?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Does the CAPA procedure include impact on data?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Does the CAPA procedure include escalation process?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Does the CAPA procedure include effectiveness check?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Does the Quality Organization review and approve exception documentation?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Is there a provision to notify the customer in a timely manner and/or request a deviation from requirements or protocols?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Is there a process for tracking and trending CAPA issues and exceptions?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Are exceptions and/or CAPAs part of the agenda for Management Review?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Does your company have a change management process and written procedures for change control?', 'answer': '', 'domain': 'Change Management', 'type': 'close-ended'}, {'question': 'Does the change management system prevent unauthorized modifications to validated systems, processes, and equipment?', 'answer': '', 'domain': 'Change Management', 'type': 'close-ended'}, {'question': 'Does the change management process ensure that documents impacted by changes are promptly revised?', 'answer': '', 'domain': 'Change Management', 'type': 'close-ended'}, {'question': 'Are proposed changes reviewed and approved by the Quality Organization and appropriate Functional Area Representatives?', 'answer': '', 'domain': 'Change Management', 'type': 'close-ended'}, {'question': 'Does the change management process require notification to customers for changes that may have impact on the service-related activities provided?', 'answer': '', 'domain': 'Change Management', 'type': 'close-ended'}, {'question': 'Does your company utilize any computerized systems in support of QMS activities?', 'answer': '', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'Does your company require validation?', 'answer': '', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'Provide the following details for any validated computerized systems utilized in support of QMS activities: System Name, Intended Use, Annex 11/21 CFR Part 11 Compliant.', 'answer': '', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Are validated electronic systems only accessible by authorized users with a unique user ID and password?', 'answer': '', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'Are access levels implemented in the electronic systems which allow only authorized users to enter data for which they are responsible?', 'answer': '', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'Is electronic data considered original data?', 'answer': '', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'Are electronic signatures used in support of QMS activities?', 'answer': '', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'Does your company have a Disaster Recovery Plan and Business Continuity Plan for the computerized systems used in support of QMS activities?', 'answer': '', 'domain': 'Technology', 'type': 'close-ended'}, {'question': 'Are there controls in place to ensure all data is attributable, legible, contemporaneous, original, and accurate (ALCOA)?', 'ans ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 13:32:49,887 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': 'N/A', 'description': 'AbbVie R&D QA Supplier Assessment Quality Questionnaire', 'qa_pairs': [{'question': 'F) Documentation of training, including On the Job training?', 'answer': '', 'domain': 'Training', 'type': 'close-ended'}, {'question': 'A26. Do all employees performing regulated activities/services receive annual refresher training on the applicable GxP Guidelines?', 'answer': '', 'domain': 'Training', 'type': 'close-ended'}, {'question': 'A27. Are all procedures, forms, and electronic systems readily available to all employees performing activities related to the services provided?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'A28. Will any contract employees be performing activities related to the services provided?', 'answer': '', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'If yes, explain how the contractor is properly trained and qualified to provide services on behalf of your company.', 'answer': '', 'domain': 'Training', 'type': 'open-ended'}, {'question': 'A29. Does your company have a process and written procedures for establishing and maintaining control of quality documents and records?', 'answer': '', 'domain': 'Documentation', 'type': 'close-ended'}, {'question': 'If yes, list applicable procedures.', 'answer': '', 'domain': 'Documentation', 'type': 'open-ended'}, {'question': 'A30. Are quality documents controlled by revision and/or date?', 'answer': '', 'domain': 'Documentation', 'type': 'close-ended'}, {'question': 'If yes, are the historical files of the revised documents retrievable?', 'answer': '', 'domain': 'Documentation', 'type': 'close-ended'}, {'question': 'A31. Is there a record retention policy for both paper and electronic records?', 'answer': '', 'domain': 'Documentation', 'type': 'close-ended'}, {'question': 'A32. Are Good Documentation Practices trained on and followed?', 'answer': '', 'domain': 'Training', 'type': 'close-ended'}, {'question': 'A33. Is there a requirement that the Quality Organization has responsibility for final approval of quality related documents?', 'answer': '', 'domain': 'Quality', 'type': 'close-ended'}, {'question': 'If yes, describe.', 'answer': '', 'domain': 'Quality', 'type': 'open-ended'}, {'question': 'A34. Does your company have a process to ensure employees are trained prior to the use of new or revised versions of documents and procedures?', 'answer': '', 'domain': 'Training', 'type': 'close-ended'}, {'question': 'If yes, describe the process.', 'answer': '', 'domain': 'Training', 'type': 'open-ended'}, {'question': 'A35. Does your company have a system to ensure that only the correct version of documents and procedures are being used and referenced?', 'answer': '', 'domain': 'Documentation', 'type': 'close-ended'}, {'question': 'A36. Is there a procedure for the storage, maintenance, and retrieval of electronic and/or paper original quality documents and data?', 'answer': '', 'domain': 'Documentation', 'type': 'close-ended'}, {'question': 'If yes, list applicable procedures.', 'answer': '', 'domain': 'Documentation', 'type': 'open-ended'}, {'question': 'A37. Does your company have a process and written procedures for the selection, approval, and oversight of suppliers?', 'answer': '', 'domain': 'Supplier Management', 'type': 'close-ended'}, {'question': 'If yes, list applicable procedures.', 'answer': '', 'domain': 'Supplier Management', 'type': 'open-ended'}, {'question': 'A38. Is the supplier’s QMS evaluated as part of the qualification/assessment process for new and existing suppliers including compliance with applicable regulations?', 'answer': '', 'domain': 'Supplier Management', 'type': 'close-ended'}, {'question': 'A39. Is there a formal process for periodically re-evaluating the acceptability of suppliers?', 'answer': '', 'domain': 'Supplier Management', 'type': 'close-ended'}, {'question': 'If yes, list applicable procedures.', 'answer': '', 'domain': 'Supplier Management', 'type': 'ope ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 13:32:49,892 - rfiprocessor.core.agents.rfi_parser - INFO - Successfully parsed document. Found 122 Q&A pairs.
# 2025-07-22 13:32:49,897 - __main__ - INFO - Saved parsed output to json_output\Cogstate Quality Management System_Quality Questionnaire Blank.json
# 2025-07-22 13:32:49,899 - __main__ - INFO - Successfully validated JSON structure for doc ID 12.
# 2025-07-22 13:32:49,902 - rfiprocessor.services.db_handler - INFO - Updating document ID 12 with: {'rfi_json_payload': {'summary': "## Solution Overview\nOur proposed solution leverages cutting-edge technology and industry best practices to deliver a comprehensive platform tailored to meet the unique needs of your organization. By integrating advanced data analytics and user-friendly interfaces, we ensure that your team can efficiently manage and analyze critical information. Our solution is designed to enhance operational efficiency and drive informed decision-making.\n\n## Technical Capabilities\nThe platform is built on a robust, scalable architecture that supports seamless integration with existing systems, ensuring minimal disruption during deployment. Advanced security features are embedded throughout the system to protect sensitive data and maintain compliance with industry standards. Our technology stack includes cloud-based services that offer high availability and reliability.\n\n## Regulatory Compliance\nWe are committed to adhering to all relevant regulatory frameworks, ensuring that our solution complies with industry standards such as HIPAA, GDPR, and other applicable regulations. Our compliance team continuously monitors changes in regulatory requirements to ensure ongoing adherence and to provide peace of mind for your organization.\n\n## Implementation Timeline\nOur implementation process follows a structured timeline that includes phases for planning, development, testing, and deployment. We anticipate a full deployment within 12 weeks, with regular updates and checkpoints to ensure alignment with your objectives. Our project management approach is designed to be flexible, accommodating any necessary adjustments.\n\n## Key Differentiators\nOur solution stands out due to its user-centric design, which prioritizes ease of use and accessibility. Additionally, we offer unparalleled customer support and a commitment to continuous improvement, ensuring that our platform evolves to meet your changing needs. Our team's deep industry expertise further enhances our ability to deliver a solution that aligns with your strategic goals.\n\n## Support and Maintenance\nWe provide comprehensive support and maintenance services to ensure the ongoing success of our solution. Our dedicated support team is available 24/7 to address any issues and provide timely assistance. Regular updates and enhancements are included as part of our service commitment, ensuring that your platform remains current and effective.\n\nCompany Name: Cogstate", 'description': "The Quality Questionnaire aims to gather detailed information about the company's quality systems and business practices. It includes questions about company structure, regulatory adherence, audits, and quality policies. Respondents are required to provide various documents such as Quality Manuals and Organizational Charts to support their responses.\n\nAbbVie R&D QA Supplier Assessment Quality Questionnaire\n\nAbbVie R&D QA Supplier Assessment Quality Questionnaire\n\nAbbVie R&D QA Supplier Assessment Quality Questionnaire", 'qa_pairs': [{'question': 'Is your company a division or subsidiary of another corporation?', 'answer': '', 'domain': 'General', 'type': 'close-ended'}, {'question': 'Is the company address the location where services will be performed?', 'answer': '', 'domain': 'General', 'type': 'close-ended'}, {'question': 'Will any part of the services be sub-contracted to another provider?', 'answer': '', 'domain': 'General', 'type': 'close-ended'}, {'question': 'List any contracts and/or quality agreements that include quality oversight responsibilities for services to be provided.', 'answer': '', 'domain': 'General', 'type': 'open-ended'}, {'question': 'What regulatory guidelines does your company adhere to at its locations for the services it provides?', 'answer': '', 'domain': 'Compliance', 'type': 'open-ended'}, {'question': 'Does your company verify that it does no ...
# 2025-07-22 13:32:49,915 - __main__ - INFO - Successfully parsed and stored JSON for document ID 12.
# Parsing RFI/RFP documents:  50%|█████     | 1/2 [01:03<01:03, 63.57s/it]2025-07-22 13:32:49,920 - __main__ - INFO - Parsing RFI/RFP document: LEXEO GCP service provider audit questionnaire Blank.docx (ID: 14)
# 2025-07-22 13:32:49,923 - rfiprocessor.core.agents.rfi_parser - INFO - Generating executive summary...
# 2025-07-22 13:32:59,560 - rfiprocessor.core.agents.rfi_parser - INFO - Splitting document into processable chunks...
# 2025-07-22 13:32:59,561 - rfiprocessor.core.agents.rfi_parser - INFO - Processing 6 chunks concurrently...
# 2025-07-22 13:32:59,562 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# |  |  |
# | --- | --- |
# | **Contract Service Provider Questionnaire** | |
# | **Service Provider Name** |  |
# | **Service Provider Address** |  |
# | **Service Provider Contact Name and Title** |  |
# | **Service Provider Contact Telephone Number** |  |
# | **Service Provider Contact E-mail** |  |
# | **Service Provider Contact Signature/Date** |  |
#
# | **Quality Assessment Inquiry** | **Response** | **Comments** |
# | --- | --- | --- |
# | **General Company Information** | | |
# | Describe your company’s general service offerings. | Yes No  N/A  See Attached |  |
# | What products or services are or would you be providing to LEXEO? | Yes No  N/A  See Attached |  |
# | How many years has your company been in business? | Yes No  N/A  See Attached |  |
# | Describe any changes in corporate structure in the last five years (e.g., mergers, acquisitions, Initial Public Offering (IPO)) | Yes No  N/A  See Attached |  |
# | Describe any planned/announced changes in corporate structure. | Yes No  N/A  See Attached |  |
# | ...
# --- END OF CHUNK ---
#
# 2025-07-22 13:32:59,567 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- CHUNK SENT TO LLM ---
# See Attached |  |
# | Are background and debarment checks performed for new employees? | Yes No  N/A  See Attached |  |
# ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 13:33:22,865 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': '', 'description': '', 'qa_pairs': [{'question': 'How are software issues reported by clinical sites or sponsors like LEXEO handled?', 'answer': 'N/A', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'How long are help desk tickets retained for?', 'answer': 'N/A', 'domain': 'Support', 'type': 'open-ended'}, {'question': 'Does your company use any open-source software? If so, how is this managed and what procedures are in place?', 'answer': 'N/A', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Describe the process used for major and minor software release planning, testing and implementation.', 'answer': 'N/A', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Describe your company’s process for managing system downtime during patches or upgrades.', 'answer': 'N/A', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Describe the process for user training on software.', 'answer': 'N/A', 'domain': 'Technology', 'type': 'open-ended'}, {'question': 'Are sponsors and regulatory authority inspectors able to access software validation information?', 'answer': 'N/A', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Does your company have a Data Privacy Officer?', 'answer': 'N/A', 'domain': 'Privacy', 'type': 'close-ended'}, {'question': 'Does your company have a Privacy Policy or SOP?', 'answer': 'N/A', 'domain': 'Privacy', 'type': 'close-ended'}, {'question': 'Does your company have assessment and reporting procedures for privacy or confidentiality breaches?', 'answer': 'N/A', 'domain': 'Privacy', 'type': 'close-ended'}, {'question': 'Does your company have procedures in place to segregate and protect unblinded trial data for blinded trials? Please describe.', 'answer': 'N/A', 'domain': 'Privacy', 'type': 'open-ended'}, {'question': 'Does your company have procedures in the event a trial participant withdraws consent?', 'answer': 'N/A', 'domain': 'Privacy', 'type': 'close-ended'}, {'question': 'Does your company maintain, control, and periodically update laboratory reference ranges?', 'answer': 'N/A', 'domain': 'Laboratory Services', 'type': 'close-ended'}, {'question': 'Does your company maintain medical oversight and prompt reporting of critical lab values?', 'answer': 'N/A', 'domain': 'Laboratory Services', 'type': 'close-ended'}, {'question': 'Does your company use validated shippers for shipment of laboratory samples?', 'answer': 'N/A', 'domain': 'Laboratory Services', 'type': 'close-ended'}, {'question': 'Are your personnel trained to laboratory safety, Environmental Health and Safety and IATA standards?', 'answer': 'N/A', 'domain': 'Laboratory Services', 'type': 'close-ended'}, {'question': 'Please provide a facility map/floorplan.', 'answer': 'N/A', 'domain': 'Laboratory Services', 'type': 'open-ended'}, {'question': 'Please describe temperature/environmental monitoring controls in your facility.', 'answer': 'N/A', 'domain': 'Laboratory Services', 'type': 'open-ended'}, {'question': 'Please describe equipment calibration, validation, and preventive maintenance procedures.', 'answer': 'N/A', 'domain': 'Laboratory Services', 'type': 'open-ended'}, {'question': 'Please describe reagent purchase, formulation, QC, and management.', 'answer': 'N/A', 'domain': 'Laboratory Services', 'type': 'open-ended'}, {'question': 'Please describe calibration standard management.', 'answer': 'N/A', 'domain': 'Laboratory Services', 'type': 'open-ended'}, {'question': 'Please describe procedures for sample management and archive, including ongoing reconciliation with the clinical database.', 'answer': 'N/A', 'domain': 'Laboratory Services', 'type': 'open-ended'}, {'question': 'Please describe method validation procedures, including accuracy, linearity, precision, specificity, limit of quantitation, etc.', 'answer': 'N/A', 'domain': 'Laboratory Services', 'type': 'open-ended'}, {'question': 'Describe procedures for trial participant recruitment, including verification of identit ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 13:33:23,468 - rfiprocessor.core.agents.rfi_parser - INFO -
# --- LLM RESPONSE FOR CHUNK ---
# {'summary': '', 'description': '', 'qa_pairs': [{'question': 'Does the system follow the structure of the TMF reference model?', 'answer': 'N/A', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Are sponsor personnel permitted to access the TMF? Please describe the process.', 'answer': 'N/A', 'domain': 'Compliance', 'type': 'open-ended'}, {'question': 'Is the TMF metadata included in the transfer of the TMF to LEXEO at the end of the study? Please describe the transfer process.', 'answer': 'N/A', 'domain': 'Compliance', 'type': 'open-ended'}, {'question': 'Does the LEXEO TMF undergo ongoing Quality Control? Please describe.', 'answer': 'N/A', 'domain': 'Compliance', 'type': 'open-ended'}, {'question': 'Does the TMF use validated signatures?', 'answer': 'N/A', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'Does your organization incorporate third party vendor documents into the TMF? Please describe the process and QC measures.', 'answer': 'N/A', 'domain': 'Compliance', 'type': 'open-ended'}, {'question': "Are there any documents that your organization considers to be 'Non-TMF' documents? If yes, please describe what they are and how they are managed.", 'answer': 'N/A', 'domain': 'Compliance', 'type': 'open-ended'}, {'question': 'Are regulatory inspectors permitted access to the TMF? If so, please describe the process.', 'answer': 'N/A', 'domain': 'Compliance', 'type': 'open-ended'}, {'question': 'Does your organization maintain business continuity/disaster recovery plans?', 'answer': 'N/A', 'domain': 'Business Continuity', 'type': 'close-ended'}, {'question': 'At what frequency are these plans tested? Are tests performed desktop only? Please attach the last three tests.', 'answer': 'N/A', 'domain': 'Business Continuity', 'type': 'open-ended'}, {'question': 'Describe physical security for your facility, including frequency of user access review.', 'answer': 'N/A', 'domain': 'Security', 'type': 'open-ended'}, {'question': 'Do you have a pest control vendor? What is the frequency of checks?', 'answer': 'N/A', 'domain': 'Facility Management', 'type': 'open-ended'}, {'question': 'Does your facility have access to backup power in the event of a power outage? For how many days?', 'answer': 'N/A', 'domain': 'Business Continuity', 'type': 'open-ended'}, {'question': 'What percentage of employees are in office versus remote?', 'answer': 'N/A', 'domain': 'Human Resources', 'type': 'open-ended'}, {'question': 'Are logical security controls in place for electronic systems? Please describe.', 'answer': 'N/A', 'domain': 'Information Technology', 'type': 'open-ended'}, {'question': 'How often are user access reviews conducted for company electronic systems?', 'answer': 'N/A', 'domain': 'Information Technology', 'type': 'open-ended'}, {'question': 'Please provide the Recovery Time Objective (RTO) and Recovery Point Objective (RPO) for any electronic systems that will apply to the LEXEO project.', 'answer': 'N/A', 'domain': 'Information Technology', 'type': 'open-ended'}, {'question': 'Has your company certified to FDA per 21 CFR 11.100 that electronic signatures are in use?', 'answer': 'N/A', 'domain': 'Compliance', 'type': 'close-ended'}, {'question': 'What system(s) does your company use for electronic signatures? How was it validated?', 'answer': 'N/A', 'domain': 'Information Technology', 'type': 'open-ended'}, {'question': 'Is multifactor authentication (MFA) required to access company systems?', 'answer': 'N/A', 'domain': 'Security', 'type': 'close-ended'}, {'question': 'How frequently are password changes forced?', 'answer': 'N/A', 'domain': 'Security', 'type': 'open-ended'}, {'question': 'Does your company maintain a list of electronic systems with GXP impact? How often are systems reviewed?', 'answer': 'N/A', 'domain': 'Compliance', 'type': 'open-ended'}, {'question': 'What systems would house LEXEO data and information?', 'answer': 'N/A', 'domain': 'Information Technology', 'type': 'open-ended'}, {'question' ...
# --- END OF LLM RESPONSE ---
#
# 2025-07-22 13:33:23,470 - rfiprocessor.core.agents.rfi_parser - INFO - Successfully parsed document. Found 157 Q&A pairs.
# 2025-07-22 13:33:23,475 - __main__ - INFO - Saved parsed output to json_output\LEXEO GCP service provider audit questionnaire Blank.json
# 2025-07-22 13:33:23,477 - __main__ - INFO - Successfully validated JSON structure for doc ID 14.
# 2025-07-22 13:33:23,480 - rfiprocessor.services.db_handler - INFO - Updating document ID 14 with: {'rfi_json_payload': {'summary': '## Solution Overview\nOur proposed solution leverages cutting-edge technology to enhance operational efficiency and drive innovation in the life sciences sector. By integrating advanced analytics and machine learning, we provide a robust platform that supports data-driven decision-making. The solution is designed to be scalable, ensuring it meets both current and future needs of the organization.\n\n## Technical Capabilities\nThe platform offers seamless integration with existing systems, ensuring minimal disruption during deployment. It is built on a secure, cloud-based architecture that provides high availability and redundancy. Our solution supports a wide range of data formats and includes powerful tools for data visualization and reporting, enabling users to gain insights quickly and effectively.\n\n## Regulatory Compliance\nWe prioritize compliance with all relevant industry regulations, including HIPAA, GDPR, and 21 CFR Part 11. Our solution includes comprehensive audit trails and data encryption to ensure the highest levels of data security and privacy. Regular updates are provided to maintain compliance with evolving regulatory requirements.\n\n## Implementation Timeline\nThe implementation process is structured to ensure a smooth transition and is typically completed within 12 to 16 weeks. Our dedicated project management team works closely with your organization to ensure all milestones are met on time. Post-implementation, we offer extensive training to ensure users are fully equipped to utilize the platform effectively.\n\n## Key Differentiators\nOur solution stands out due to its user-friendly interface, which requires minimal training for effective use. The platform’s ability to integrate with a wide range of third-party applications sets it apart from competitors. Additionally, our commitment to customer service ensures that clients receive ongoing support and customization as needed.\n\n## Support and Maintenance\nWe provide 24/7 customer support with a dedicated team of experts ready to assist with any technical issues. Our maintenance package includes regular software updates and performance monitoring to ensure optimal system functionality. Clients also have access to an extensive knowledge base and user community for additional support resources.\n\nCompany Name: Cogstate', 'description': 'The document is a Contract Service Provider Questionnaire that includes inquiries about general company information, quality assurance, and other related aspects. It is structured in a tabular format where questions are posed with options for responses and comments.', 'qa_pairs': [{'question': 'Describe your company’s general service offerings.', 'answer': 'See Attached', 'domain': 'General', 'type': 'open-ended'}, {'question': 'What products or services are or would you be providing to LEXEO?', 'answer': 'See Attached', 'domain': 'General', 'type': 'open-ended'}, {'question': 'How many years has your company been in business?', 'answer': 'See Attached', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Describe any changes in corporate structure in the last five years (e.g., mergers, acquisitions, Initial Public Offering (IPO))', 'answer': 'See Attached', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Describe any planned/announced changes in corporate structure.', 'answer': 'See Attached', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Please provide the worldwide number of personnel, including contractors/consultants.', 'answer': 'See Attached', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Please provide the number of employees, contractors, and consultants in the United States.', 'answer': 'See Attached', 'domain': 'General', 'type': 'open-ended'}, {'question': 'Please provide the number of employees, contractors, and consultants in the European ...
# 2025-07-22 13:33:23,488 - __main__ - INFO - Successfully parsed and stored JSON for document ID 14.
# Parsing RFI/RFP documents: 100%|██████████| 2/2 [01:37<00:00, 48.57s/it]
# 2025-07-22 13:33:23,492 - __main__ - INFO - --- Ingestion Pipeline Finished ---
# 2025-07-22 13:33:23,493 - __main__ - INFO - Application finished.

# %%
from rfiprocessor.db.database import get_db_session
from rfiprocessor.services.db_handler import DatabaseHandler
from rfiprocessor.db.db_models import Document, IngestionStatus
from rfiprocessor.services.chunker import ChunkerService
from config.config import Config

# Setup config and chunker
config = Config()
chunk_size = getattr(config, "CHUNK_SIZE", 1000)
chunk_overlap = getattr(config, "CHUNK_OVERLAP", 150)
chunker = ChunkerService(chunk_size=chunk_size, chunk_overlap=chunk_overlap)

# Get a database session and handler
db_session_generator = get_db_session()
db_session = next(db_session_generator)
db_handler = DatabaseHandler(db_session)

# Fetch all documents
docs = db_session.query(Document).all()
if not docs:
    raise ValueError("No documents found in the database.")

for doc in docs:
    print("="*60)
    print(f"Document: {doc.source_filename} (type: {doc.document_type})")
    try:
        if doc.document_type == "RFI/RFP" and doc.rfi_json_payload:
            markdown_content = ""  # Not used for RFI/RFP
            print("Chunking as RFI/RFP (using JSON payload)...")
        elif doc.markdown_filepath:
            with open(doc.markdown_filepath, 'r', encoding='utf-8') as f:
                markdown_content = f.read()
            print("Chunking as supporting document (using markdown content)...")
        else:
            print("Skipping: Document is missing required data for chunking.")
            continue

        chunks_data = chunker.create_chunks_for_document(doc, markdown_content)
        print(f"Number of chunks: {len(chunks_data)}")

        if chunks_data:
            db_handler.add_chunks_to_document(doc.id, chunks_data)
            # Optionally, update the document status to CHUNKED
            db_handler.update_document(doc.id, {"ingestion_status": IngestionStatus.CHUNKED})
            print("Chunks saved to database.")
        else:
            print("No chunks created for this document.")

    except Exception as e:
        print(f"Error processing document: {e}")

print("="*60)
print("Done chunking and saving all documents.")
# Out:
# 2025-07-22 13:33:23,563 - rfiprocessor.services.chunker - INFO - ChunkerService initialized with chunk_size=2000 and chunk_overlap=200
# 2025-07-22 13:33:23,569 - rfiprocessor.services.chunker - INFO - Creating chunks for document ID 3 (Type: RFI/RFP)
# 2025-07-22 13:33:23,570 - rfiprocessor.services.chunker - INFO - Created 135 Q&A-based chunks for document ID 3.
# 2025-07-22 13:33:23,590 - rfiprocessor.services.db_handler - INFO - Added 135 chunks to document ID 3.
# 2025-07-22 13:33:23,633 - rfiprocessor.services.db_handler - INFO - Updating document ID 3 with: {'ingestion_status': <IngestionStatus.CHUNKED: 'CHUNKED'>}
# 2025-07-22 13:33:23,636 - rfiprocessor.services.chunker - INFO - Creating chunks for document ID 5 (Type: Supporting Document)
# 2025-07-22 13:33:23,637 - rfiprocessor.services.chunker - WARNING - Markdown content for document ID 5 is empty. Skipping chunking.
# 2025-07-22 13:33:23,654 - rfiprocessor.services.chunker - INFO - Creating chunks for document ID 6 (Type: Supporting Document)
# 2025-07-22 13:33:23,656 - rfiprocessor.services.chunker - INFO - Created 2 semantic chunks for document ID 6.
# 2025-07-22 13:33:23,665 - rfiprocessor.services.db_handler - INFO - Added 2 chunks to document ID 6.
# 2025-07-22 13:33:23,670 - rfiprocessor.services.db_handler - INFO - Updating document ID 6 with: {'ingestion_status': <IngestionStatus.CHUNKED: 'CHUNKED'>}
# 2025-07-22 13:33:23,676 - rfiprocessor.services.chunker - INFO - Creating chunks for document ID 7 (Type: Supporting Document)
# 2025-07-22 13:33:23,678 - rfiprocessor.services.chunker - WARNING - Markdown content for document ID 7 is empty. Skipping chunking.
# 2025-07-22 13:33:23,681 - rfiprocessor.services.chunker - INFO - Creating chunks for document ID 9 (Type: RFI/RFP)
# 2025-07-22 13:33:23,682 - rfiprocessor.services.chunker - INFO - Created 87 Q&A-based chunks for document ID 9.
# 2025-07-22 13:33:23,696 - rfiprocessor.services.db_handler - INFO - Added 87 chunks to document ID 9.
# 2025-07-22 13:33:23,734 - rfiprocessor.services.db_handler - INFO - Updating document ID 9 with: {'ingestion_status': <IngestionStatus.CHUNKED: 'CHUNKED'>}
# 2025-07-22 13:33:23,738 - rfiprocessor.services.chunker - INFO - Creating chunks for document ID 10 (Type: RFI/RFP)
# 2025-07-22 13:33:23,739 - rfiprocessor.services.chunker - INFO - Created 47 Q&A-based chunks for document ID 10.
# 2025-07-22 13:33:23,751 - rfiprocessor.services.db_handler - INFO - Added 47 chunks to document ID 10.
# ============================================================
# Document: .DS_Store (type: None)
# Skipping: Document is missing required data for chunking.
# ============================================================
# Document: Copy of AbbVie Remediation Assessment- IT Security Privacy- Cogstate v10 (Additional Info) 3 Feb 2016.xlsx (type: None)
# Skipping: Document is missing required data for chunking.
# ============================================================
# Document: Cogstate_RFI_AbbVie S&E Vendor Communication Plan.docx (type: RFI/RFP)
# Chunking as RFI/RFP (using JSON payload)...
# Number of chunks: 135
# Chunks saved to database.
# ============================================================
# Document: Attachment 2.xlsx (type: None)
# Skipping: Document is missing required data for chunking.
# ============================================================
# Document: Corporate Org Chart.pdf (type: Supporting Document)
# Chunking as supporting document (using markdown content)...
# Number of chunks: 0
# No chunks created for this document.
# ============================================================
# Document: Attachment 1 - ISO Certificate.pdf (type: Supporting Document)
# Chunking as supporting document (using markdown content)...
# Number of chunks: 2
# Chunks saved to database.
# ============================================================
# Document: Abbvie.pdf (type: Supporting Document)
# Chunking as supporting document (using markdown content)...
# Number of chunks: 0
# No chunks created for this document.
# ============================================================
# Document: AbbVie_Recruitment Survey_Cogstate 2016 -FINAL.doc (type: None)
# Skipping: Document is missing required data for chunking.
# ============================================================
# Document: Cogstate_Acadia_CHDR_Ph1 Challenge_HV_CT QualityQuestionnaire_SoftwareSupplier_28 Jan 2022_V1.0.pdf (type: RFI/RFP)
# Chunking as RFI/RFP (using JSON payload)...
# Number of chunks: 87
# Chunks saved to database.
# ============================================================
# Document: ADDF ACCESS Request for Information.docx (type: RFI/RFP)
# Chunking as RFI/RFP (using JSON payload)...
# Number of chunks: 47
# 2025-07-22 13:33:23,773 - rfiprocessor.services.db_handler - INFO - Updating document ID 10 with: {'ingestion_status': <IngestionStatus.CHUNKED: 'CHUNKED'>}
# 2025-07-22 13:33:23,779 - rfiprocessor.services.chunker - INFO - Creating chunks for document ID 12 (Type: RFI/RFP)
# 2025-07-22 13:33:23,780 - rfiprocessor.services.chunker - INFO - Created 122 Q&A-based chunks for document ID 12.
# 2025-07-22 13:33:23,794 - rfiprocessor.services.db_handler - INFO - Added 122 chunks to document ID 12.
# 2025-07-22 13:33:23,847 - rfiprocessor.services.db_handler - INFO - Updating document ID 12 with: {'ingestion_status': <IngestionStatus.CHUNKED: 'CHUNKED'>}
# 2025-07-22 13:33:23,857 - rfiprocessor.services.chunker - INFO - Creating chunks for document ID 14 (Type: RFI/RFP)
# 2025-07-22 13:33:23,860 - rfiprocessor.services.chunker - INFO - Created 157 Q&A-based chunks for document ID 14.
# 2025-07-22 13:33:23,876 - rfiprocessor.services.db_handler - INFO - Added 157 chunks to document ID 14.
# 2025-07-22 13:33:23,925 - rfiprocessor.services.db_handler - INFO - Updating document ID 14 with: {'ingestion_status': <IngestionStatus.CHUNKED: 'CHUNKED'>}
# Chunks saved to database.
# ============================================================
# Document: .DS_Store (type: None)
# Skipping: Document is missing required data for chunking.
# ============================================================
# Document: Cogstate Quality Management System_Quality Questionnaire Blank.pdf (type: RFI/RFP)
# Chunking as RFI/RFP (using JSON payload)...
# Number of chunks: 122
# Chunks saved to database.
# ============================================================
# Document: Diligent Pharma - Harmony Biosciences Core RFI 3.0 - 27-01-2025 Blank.xlsx (type: None)
# Skipping: Document is missing required data for chunking.
# ============================================================
# Document: LEXEO GCP service provider audit questionnaire Blank.docx (type: RFI/RFP)
# Chunking as RFI/RFP (using JSON payload)...
# Number of chunks: 157
# Chunks saved to database.
# ============================================================
# Done chunking and saving all documents.

# %%
import os
import shutil
from tqdm import tqdm

# --- Core Application Imports ---
from config.config import Config
from rfiprocessor.utils.logger import get_logger
from rfiprocessor.core.agents.rfi_parser import RfiParserAgent

# --- Database Imports ---
from rfiprocessor.db.database import init_db, get_db_session
from rfiprocessor.services.db_handler import DatabaseHandler
from rfiprocessor.db.db_models import IngestionStatus
from rfiprocessor.models.data_models import RFIJson

# --- Initial Setup ---
config = Config()
logger = get_logger(__name__)


def run_chunking_pipeline():
    """
    Scans for new files and processes them through the ingestion pipeline.
    """
    logger.info("--- Starting Ingestion Pipeline ---")

    # Initialize services and agents
    chunker = ChunkerService(config.CHUNK_SIZE, config. CHUNK_OVERLAP)

    db_session_generator = get_db_session()
    db_session = next(db_session_generator)
    try:
        db_handler = DatabaseHandler(db_session)
        # --- Step 4: Document Chunking ---
        logger.info("--- Starting Document Chunking Step ---")
        docs_to_chunk = db_handler.get_documents_by_status(IngestionStatus.PARSED)

        if not docs_to_chunk:
            logger.info("No new parsed documents to chunk.")
        else:
            logger.info(f"Found {len(docs_to_chunk)} documents to chunk.")

        for doc in tqdm(docs_to_chunk, desc="Chunking documents"):
            try:
                logger.info(f"Chunking document: {doc.source_filename} (ID: {doc.id})")
                
                # We need the markdown content for supporting docs.
                # RFI docs don't need it for chunking, but it's cleaner to always have it.
                with open(doc.markdown_filepath, 'r', encoding='utf-8') as f:
                    markdown_content = f.read()
                    
                # Call the chunker service
                chunks_data = chunker.create_chunks_for_document(doc, markdown_content)
                
                if not chunks_data:
                    logger.warning(f"No chunks were created for document ID {doc.id}. Moving to next stage.")
                else:
                    # Add the created chunks to the database
                    db_handler.add_chunks_to_document(doc.id, chunks_data)
                
                # Update the document status to CHUNKED
                db_handler.update_document(doc.id, {"ingestion_status": IngestionStatus.CHUNKED})
                logger.info(f"Successfully chunked and stored chunks for document ID {doc.id}.")

            except Exception as e:
                error_msg = f"Error chunking document ID {doc.id}: {e}"
                logger.error(error_msg, exc_info=True)
                db_handler.update_document(
                    doc.id,
                    {"ingestion_status": IngestionStatus.FAILED, "error_message": error_msg}
                )

    finally:
        db_session.close()
        logger.info("--- Ingestion Pipeline Finished ---")

# The if __name__ == "__main__": block remains the same
if __name__ == "__main__":
    logger.info("Application started.")
    init_db()
    run_ingestion_pipeline()
    logger.info("Application finished.")
# Out:
# 2025-07-22 13:33:23,945 - __main__ - INFO - Application started.
# 2025-07-22 13:33:23,946 - rfiprocessor.db.database - INFO - Initializing database and creating tables if they don't exist...
# 2025-07-22 13:33:23,950 - rfiprocessor.db.database - INFO - Database initialization complete.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 81
#      79 logger.info("Application started.")
#      80 init_db()
# ---> 81 run_ingestion_pipeline()
#      82 logger.info("Application finished.")
#
# NameError: name 'run_ingestion_pipeline' is not defined
